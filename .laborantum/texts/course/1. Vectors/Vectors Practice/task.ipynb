# %% [markdown]
# # Vectors Practice

# %% [markdown]
# In this chapter we will work with vectors and code Gramm-Schmidt Orthonormalization Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
import lovely_numpy as ln
import json_tricks

# %%
inputs = json_tricks.load('/Users/thanakritp/Documents/Thanakrit_workspace/Class/linear-algrebra-1/linear-algebra-part-1/.laborantum/texts/course/1. Vectors/Vectors Practice/inputs/inputs.json')
# inputs1 = json_tricks.load('.inputs2.json')

answers = {}

# %% [markdown]
# In your input you have arrys of shape $N \times 2$, which means that you have 2 vectors both having N coordinates

# %%
for one_input in inputs:
    print(one_input)
    print(ln.lovely(one_input['X']))
# Out:
# OrderedDict({'X': array([[  2,   5],
#        [-10,  -7]])})
# array[2, 2] i64 n=4 x∈[-10, 5] μ=-2.500 σ=6.185 [[2, 5], [-10, -7]]
# OrderedDict({'X': array([[-7, -3],
#        [-1,  9],
#        [ 8, -6],
#        [-4,  2],
#        [-9, -4]])})
# array[5, 2] i64 n=10 x∈[-9, 9] μ=-1.500 σ=5.784 [[-7, -3], [-1, 9], [8, -6], [-4, 2], [-9, -4]]
# OrderedDict({'X': array([[  4,   7],
#        [ -5,   3],
#        [ -2,  -1],
#        [  9,   6],
#        [  9,  -5],
#        [  5,   5],
#        [-10,   8],
#        [ -7,   7],
#        [  9,   9]])})
# array[9, 2] i64 n=18 x∈[-10, 9] μ=2.833 σ=6.039
# OrderedDict({'X': array([[  4,  -3],
#        [-10,  -9],
#        [ -1, -10],
#        [  0,  -7],
#        [  1,   8]])})
# array[5, 2] i64 n=10 x∈[-10, 8] μ=-2.700 σ=5.900 [[4, -3], [-10, -9], [-1, -10], [0, -7], [1, 8]]
# OrderedDict({'X': array([[ -8, -10],
#        [-10,  -6],
#        [ -5,  -4],
#        [ -2,   7],
#        [  5,  -6],
#        [ -1,   0],
#        [ -9,  -9],
#        [ -3,  -1],
#        [ -7,  -4]])})
# array[9, 2] i64 n=18 x∈[-10, 7] μ=-4.056 σ=4.696
# OrderedDict({'X': array([[  1,   4],
#        [  8, -10],
#        [  4,  -7],
#        [  2,   0],
#        [  1,  -6],
#        [ -4,  -6],
#        [  5,  -7],
#        [  2,  -6],
#        [ -2,   4]])})
# array[9, 2] i64 n=18 x∈[-10, 8] μ=-0.944 σ=5.038
# OrderedDict({'X': array([[ -7,   5],
#        [  3,   6],
#        [  7,  -5],
#        [ -1,  -7],
#        [-10,  -5],
#        [-10,   7],
#        [  8,  -6],
#        [ -8,   6],
#        [ -7,  -8]])})
# array[9, 2] i64 n=18 x∈[-10, 8] μ=-1.778 σ=6.554
# OrderedDict({'X': array([[  3,   6],
#        [ -3,  -1],
#        [-10,   0],
#        [  8,   1]])})
# array[4, 2] i64 n=8 x∈[-10, 8] μ=0.500 σ=5.220 [[3, 6], [-3, -1], [-10, 0], [8, 1]]
# OrderedDict({'X': array([[-8, -8],
#        [-7, -7],
#        [ 8,  4],
#        [-7,  7]])})
# array[4, 2] i64 n=8 x∈[-8, 8] μ=-2.250 σ=6.741 [[-8, -8], [-7, -7], [8, 4], [-7, 7]]
# OrderedDict({'X': array([[ 4, -1],
#        [-9, -6],
#        [ 0,  1],
#        [-2,  1]])})
# array[4, 2] i64 n=8 x∈[-9, 4] μ=-1.500 σ=3.905 [[4, -1], [-9, -6], [0, 1], [-2, 1]]
# OrderedDict({'X': array([[  9,   6],
#        [-10, -10],
#        [ -4,   9],
#        [  4,   0]])})
# array[4, 2] i64 n=8 x∈[-10, 9] μ=0.500 σ=7.314 [[9, 6], [-10, -10], [-4, 9], [4, 0]]
# OrderedDict({'X': array([[-2,  3],
#        [-8, -7],
#        [-8,  1],
#        [ 3,  6],
#        [-2, -2]])})
# array[5, 2] i64 n=10 x∈[-8, 6] μ=-1.600 σ=4.673 [[-2, 3], [-8, -7], [-8, 1], [3, 6], [-2, -2]]
# OrderedDict({'X': array([[ -2,  -8],
#        [ -7,   2],
#        [  4, -10],
#        [ -6,  -7],
#        [  3,   1]])})
# array[5, 2] i64 n=10 x∈[-10, 4] μ=-3.000 σ=4.919 [[-2, -8], [-7, 2], [4, -10], [-6, -7], [3, 1]]
# OrderedDict({'X': array([[  3,   3],
#        [  1,   6],
#        [  4,   6],
#        [  9,  -9],
#        [ -2, -10],
#        [ -6,  -4]])})
# array[6, 2] i64 n=12 x∈[-10, 9] μ=0.083 σ=5.951
# OrderedDict({'X': array([[ 3, -3],
#        [ 5, -1],
#        [ 8, -2],
#        [ 5,  1],
#        [-4,  5],
#        [-9,  2],
#        [-7,  8]])})
# array[7, 2] i64 n=14 x∈[-9, 8] μ=0.786 σ=5.129
# OrderedDict({'X': array([[ -7,   0],
#        [  2,  -4],
#        [ -7,  -5],
#        [  1, -10],
#        [  1,  -2],
#        [  0,   1],
#        [ -5,   5],
#        [ -2,  -8],
#        [  9,   9]])})
# array[9, 2] i64 n=18 x∈[-10, 9] μ=-1.222 σ=5.287
# OrderedDict({'X': array([[-7, -7],
#        [-3, -1],
#        [-1, -1],
#        [-7,  4],
#        [ 8,  2],
#        [-7, -1],
#        [ 0,  3],
#        [-3, -3]])})
# array[8, 2] i64 n=16 x∈[-7, 8] μ=-1.500 σ=4.213
# OrderedDict({'X': array([[ -9,   2],
#        [ -8,  -8],
#        [ -9,  -5],
#        [ -2,  -6],
#        [-10,   1],
#        [ -8,  -5],
#        [  6,  -2]])})
# array[7, 2] i64 n=14 x∈[-10, 6] μ=-4.500 σ=4.671
# OrderedDict({'X': array([[-9,  7],
#        [ 6, -7],
#        [-2, -6],
#        [ 6, -7],
#        [-3, -7],
#        [ 8,  7],
#        [-9,  8]])})
# array[7, 2] i64 n=14 x∈[-9, 8] μ=-0.571 σ=6.821
# OrderedDict({'X': array([[-8, -5],
#        [-5,  2],
#        [ 2, -8]])})
# array[3, 2] i64 n=6 x∈[-8, 2] μ=-3.667 σ=4.190 [[-8, -5], [-5, 2], [2, -8]]
# OrderedDict({'X': array([[ -3,  -3],
#        [  1,   7],
#        [ -4,  -3],
#        [  8,   1],
#        [  9,   7],
#        [ -1,   4],
#        [ -1,   8],
#        [-10,  -1],
#        [  1,   7]])})
# array[9, 2] i64 n=18 x∈[-10, 9] μ=1.500 σ=5.167
# OrderedDict({'X': array([[-10,   6],
#        [  0,  -6],
#        [ -7,   9]])})
# array[3, 2] i64 n=6 x∈[-10, 9] μ=-1.333 σ=6.968 [[-10, 6], [0, -6], [-7, 9]]
# OrderedDict({'X': array([[  4, -10],
#        [  9,  -2]])})
# array[2, 2] i64 n=4 x∈[-10, 9] μ=0.250 σ=7.084 [[4, -10], [9, -2]]
# OrderedDict({'X': array([[  3,   7],
#        [-10,   1],
#        [ -6, -10],
#        [  0,   4],
#        [  8,  -6],
#        [ -7,   9],
#        [ -3,  -2],
#        [  3,  -5],
#        [-10,  -2]])})
# array[9, 2] i64 n=18 x∈[-10, 9] μ=-1.444 σ=6.030
# OrderedDict({'X': array([[ 5,  1],
#        [-6, -3],
#        [ 3,  0],
#        [ 4,  7],
#        [ 9, -7],
#        [-1,  8],
#        [-8,  9],
#        [ 1,  8],
#        [ 3, -9]])})
# array[9, 2] i64 n=18 x∈[-9, 9] μ=1.333 σ=5.812
# OrderedDict({'X': array([[ 0,  6],
#        [ 6, -7],
#        [ 7,  0],
#        [-1,  2],
#        [ 3, -4],
#        [-4, -3],
#        [-2,  3],
#        [-3,  6]])})
# array[8, 2] i64 n=16 x∈[-7, 7] μ=0.562 σ=4.168
# OrderedDict({'X': array([[ 5, -2],
#        [-7, -4]])})
# array[2, 2] i64 n=4 x∈[-7, 5] μ=-2.000 σ=4.416 [[5, -2], [-7, -4]]
# OrderedDict({'X': array([[-3, -8],
#        [ 6,  8],
#        [ 3, -6]])})
# array[3, 2] i64 n=6 x∈[-8, 8] μ=0. σ=6.028 [[-3, -8], [6, 8], [3, -6]]
# OrderedDict({'X': array([[  2,   7],
#        [ -9,  -5],
#        [ -9,   9],
#        [  9,  -3],
#        [ -1,   7],
#        [ -1, -10]])})
# array[6, 2] i64 n=12 x∈[-10, 9] μ=-0.333 σ=6.835
# OrderedDict({'X': array([[-6,  7],
#        [ 6, -7],
#        [ 0, -9],
#        [-6, -6],
#        [ 6,  6]])})
# array[5, 2] i64 n=10 x∈[-9, 7] μ=-0.900 σ=6.220 [[-6, 7], [6, -7], [0, -9], [-6, -6], [6, 6]]
# OrderedDict({'X': array([[ 0,  3],
#        [-2,  1],
#        [-4, -1],
#        [ 5, -7],
#        [ 9,  2],
#        [ 8,  7],
#        [ 0, -8],
#        [-9,  1],
#        [-7,  2]])})
# array[9, 2] i64 n=18 x∈[-9, 9] μ=0. σ=5.281
# OrderedDict({'X': array([[ -9,   7],
#        [-10,  -3],
#        [ -6,  -7],
#        [ -5,  -4],
#        [ -7,  -8],
#        [ -2,  -9]])})
# array[6, 2] i64 n=12 x∈[-10, 7] μ=-5.250 σ=4.399
# OrderedDict({'X': array([[ -6, -10],
#        [  3,   9],
#        [ -1,  -5],
#        [ -9,  -3],
#        [ -2,  -3],
#        [ -7,   2]])})
# array[6, 2] i64 n=12 x∈[-10, 9] μ=-2.667 σ=5.185
# OrderedDict({'X': array([[ -4,  -3],
#        [  9, -10],
#        [ -5,   1],
#        [ -1,   9],
#        [ -3,  -5]])})
# array[5, 2] i64 n=10 x∈[-10, 9] μ=-1.200 σ=5.776 [[-4, -3], [9, -10], [-5, 1], [-1, 9], [-3, -5]]
# OrderedDict({'X': array([[ -2,   1],
#        [  4, -10],
#        [ -2,   9],
#        [ -4,   0],
#        [  9,  -8],
#        [-10,   9]])})
# array[6, 2] i64 n=12 x∈[-10, 9] μ=-0.333 σ=6.749
# OrderedDict({'X': array([[  4, -10],
#        [  9,  -4],
#        [ -9,   2],
#        [  8,   3]])})
# array[4, 2] i64 n=8 x∈[-10, 9] μ=0.375 σ=6.800 [[4, -10], [9, -4], [-9, 2], [8, 3]]
# OrderedDict({'X': array([[-6,  7],
#        [-7, -8],
#        [ 3,  5]])})
# array[3, 2] i64 n=6 x∈[-8, 7] μ=-1.000 σ=6.137 [[-6, 7], [-7, -8], [3, 5]]
# OrderedDict({'X': array([[-6, -1],
#        [-6,  7],
#        [ 8,  3],
#        [ 3, -8],
#        [-7, -1],
#        [ 2,  5],
#        [-8,  9],
#        [-4,  4],
#        [ 6,  5]])})
# array[9, 2] i64 n=18 x∈[-8, 9] μ=0.611 σ=5.668
# OrderedDict({'X': array([[ -2, -10],
#        [  0,   1],
#        [  3,  -3],
#        [ -4,   3]])})
# array[4, 2] i64 n=8 x∈[-10, 3] μ=-1.500 σ=4.031 [[-2, -10], [0, 1], [3, -3], [-4, 3]]
# OrderedDict({'X': array([[ 5, -1],
#        [-4,  1],
#        [ 8, -3],
#        [-9, -1],
#        [-8,  8],
#        [ 4, -5],
#        [-6,  8]])})
# array[7, 2] i64 n=14 x∈[-9, 8] μ=-0.214 σ=5.772
# OrderedDict({'X': array([[  4,   8],
#        [ -9,   2],
#        [-10,  -1],
#        [  6,  -8],
#        [ -2,   9],
#        [  0,   6]])})
# array[6, 2] i64 n=12 x∈[-10, 9] μ=0.417 σ=6.357
# OrderedDict({'X': array([[ -9, -10],
#        [ -5,  -8],
#        [  5,  -7],
#        [  4,  -5]])})
# array[4, 2] i64 n=8 x∈[-10, 5] μ=-4.375 σ=5.384 [[-9, -10], [-5, -8], [5, -7], [4, -5]]
# OrderedDict({'X': array([[ 9, -4],
#        [-4,  9],
#        [-4, -8],
#        [-4, -5],
#        [-5,  3]])})
# array[5, 2] i64 n=10 x∈[-8, 9] μ=-1.300 σ=5.763 [[9, -4], [-4, 9], [-4, -8], [-4, -5], [-5, 3]]
# OrderedDict({'X': array([[-6,  3],
#        [ 7, -7],
#        [ 3,  9]])})
# array[3, 2] i64 n=6 x∈[-7, 9] μ=1.500 σ=6.048 [[-6, 3], [7, -7], [3, 9]]
# OrderedDict({'X': array([[-2,  3],
#        [-5,  6],
#        [ 4, -5],
#        [-9, -5]])})
# array[4, 2] i64 n=8 x∈[-9, 6] μ=-1.625 σ=4.998 [[-2, 3], [-5, 6], [4, -5], [-9, -5]]
# OrderedDict({'X': array([[ 2,  0],
#        [ 4, -2],
#        [-3,  3],
#        [-5,  5],
#        [ 0, -7],
#        [ 0,  8],
#        [-7,  4],
#        [ 8, -5]])})
# array[8, 2] i64 n=16 x∈[-7, 8] μ=0.312 σ=4.727
# OrderedDict({'X': array([[-6,  7],
#        [-5, -7],
#        [-5, -2],
#        [-6,  7]])})
# array[4, 2] i64 n=8 x∈[-7, 7] μ=-2.125 σ=5.441 [[-6, 7], [-5, -7], [-5, -2], [-6, 7]]
# OrderedDict({'X': array([[ -9,   8],
#        [ -9,   4],
#        [  7,  -3],
#        [  1,   4],
#        [  6,  -9],
#        [  7,   2],
#        [  4, -10],
#        [ -8,   9],
#        [  4,   8]])})
# array[9, 2] i64 n=18 x∈[-10, 9] μ=0.889 σ=6.724
# OrderedDict({'X': array([[ -1,   4],
#        [-10,   2],
#        [ -1,   8],
#        [ -6,  -3],
#        [ -7,   6]])})
# array[5, 2] i64 n=10 x∈[-10, 8] μ=-0.800 σ=5.564 [[-1, 4], [-10, 2], [-1, 8], [-6, -3], [-7, 6]]
# OrderedDict({'X': array([[-5,  3],
#        [ 6,  3],
#        [ 8,  9],
#        [ 7, -3],
#        [ 7,  4],
#        [-7,  0]])})
# array[6, 2] i64 n=12 x∈[-7, 9] μ=2.667 σ=5.088
# OrderedDict({'X': array([[ 0, -9],
#        [ 6,  0],
#        [ 8,  6],
#        [-8, -4],
#        [-1, -8],
#        [ 2, -1]])})
# array[6, 2] i64 n=12 x∈[-9, 8] μ=-0.750 σ=5.479
# OrderedDict({'X': array([[-6, -6],
#        [-1,  0],
#        [ 2, -2]])})
# array[3, 2] i64 n=6 x∈[-6, 2] μ=-2.167 σ=2.967 [[-6, -6], [-1, 0], [2, -2]]
# OrderedDict({'X': array([[ -5,  -3],
#        [-10,  -9],
#        [ -7,   8]])})
# array[3, 2] i64 n=6 x∈[-10, 8] μ=-4.333 σ=5.991 [[-5, -3], [-10, -9], [-7, 8]]
# OrderedDict({'X': array([[ 8, -2],
#        [ 8, -3]])})
# array[2, 2] i64 n=4 x∈[-3, 8] μ=2.750 σ=5.262 [[8, -2], [8, -3]]
# OrderedDict({'X': array([[  8,  -7],
#        [  2,   9],
#        [  3, -10],
#        [  0,  -7]])})
# array[4, 2] i64 n=8 x∈[-10, 9] μ=-0.250 σ=6.666 [[8, -7], [2, 9], [3, -10], [0, -7]]
# OrderedDict({'X': array([[ -7,  -4],
#        [  9,  -8],
#        [  8,   8],
#        [ -4,   1],
#        [-10,  -6],
#        [  3,  -1],
#        [ -8,  -9],
#        [  2,   5]])})
# array[8, 2] i64 n=16 x∈[-10, 9] μ=-1.312 σ=6.361
# OrderedDict({'X': array([[-9,  2],
#        [-5, -4],
#        [-9,  0],
#        [-4, -4],
#        [-4, -4],
#        [ 1,  8],
#        [ 8,  8],
#        [ 9, -8]])})
# array[8, 2] i64 n=16 x∈[-9, 9] μ=-0.938 σ=6.098
# OrderedDict({'X': array([[-1,  9],
#        [-2, -5],
#        [ 1, -9],
#        [ 1,  5],
#        [ 2,  5],
#        [ 2,  8]])})
# array[6, 2] i64 n=12 x∈[-9, 9] μ=1.333 σ=4.955
# OrderedDict({'X': array([[ 3,  2],
#        [-1, -4],
#        [-6,  6]])})
# array[3, 2] i64 n=6 x∈[-6, 6] μ=0. σ=4.123 [[3, 2], [-1, -4], [-6, 6]]
# OrderedDict({'X': array([[-5,  5],
#        [-5, -5]])})
# array[2, 2] i64 n=4 x∈[-5, 5] μ=-2.500 σ=4.330 [[-5, 5], [-5, -5]]
# OrderedDict({'X': array([[  7, -10],
#        [  6,   6],
#        [-10,   0],
#        [  2, -10],
#        [ -3,   9]])})
# array[5, 2] i64 n=10 x∈[-10, 9] μ=-0.300 σ=7.170 [[7, -10], [6, 6], [-10, 0], [2, -10], [-3, 9]]
# OrderedDict({'X': array([[ -6,   9],
#        [ -6,  -5],
#        [  2,   7],
#        [  9,   2],
#        [ -4,  -3],
#        [  6, -10],
#        [  5,   0]])})
# array[7, 2] i64 n=14 x∈[-10, 9] μ=0.429 σ=5.973
# OrderedDict({'X': array([[-7, -7],
#        [ 6,  6],
#        [-1, -5],
#        [ 6,  7],
#        [-1,  2],
#        [ 5, -4]])})
# array[6, 2] i64 n=12 x∈[-7, 7] μ=0.583 σ=5.187
# OrderedDict({'X': array([[-9, -6],
#        [ 6, -6],
#        [-3,  4],
#        [-3, -8],
#        [ 6,  5],
#        [ 5,  8],
#        [ 1,  4],
#        [-3, -8]])})
# array[8, 2] i64 n=16 x∈[-9, 8] μ=-0.438 σ=5.722
# OrderedDict({'X': array([[  7,  -7],
#        [ -3,   3],
#        [  6,  -5],
#        [ -6,   3],
#        [ -5,   9],
#        [  1,  -2],
#        [-10,   7],
#        [ -5,  -6]])})
# array[8, 2] i64 n=16 x∈[-10, 9] μ=-0.812 σ=5.769
# OrderedDict({'X': array([[-5,  6],
#        [-4, -2],
#        [ 9, -6]])})
# array[3, 2] i64 n=6 x∈[-6, 9] μ=-0.333 σ=5.735 [[-5, 6], [-4, -2], [9, -6]]
# OrderedDict({'X': array([[ 0,  0],
#        [-7, -5],
#        [-1, -2],
#        [ 7,  9],
#        [-2,  0],
#        [-9,  4]])})
# array[6, 2] i64 n=12 x∈[-9, 9] μ=-0.500 σ=5.058
# OrderedDict({'X': array([[  6,  -7],
#        [ -3,  -9],
#        [ -2, -10],
#        [ -5,   5],
#        [ -4,   5],
#        [ -5,  -1],
#        [  7,   6]])})
# array[7, 2] i64 n=14 x∈[-10, 7] μ=-1.214 σ=5.734
# OrderedDict({'X': array([[ 1,  4],
#        [-5,  9]])})
# array[2, 2] i64 n=4 x∈[-5, 9] μ=2.250 σ=5.068 [[1, 4], [-5, 9]]
# OrderedDict({'X': array([[  3,   1],
#        [  1,  -9],
#        [ -3,   6],
#        [ -3,   5],
#        [-10,  -6],
#        [  8,  -8],
#        [ -2,   0],
#        [ -5,  -4],
#        [ -4,  -6]])})
# array[9, 2] i64 n=18 x∈[-10, 8] μ=-2.000 σ=5.055
# OrderedDict({'X': array([[-6, -5],
#        [-5, -4],
#        [-7,  7]])})
# array[3, 2] i64 n=6 x∈[-7, 7] μ=-3.333 σ=4.714 [[-6, -5], [-5, -4], [-7, 7]]
# OrderedDict({'X': array([[ 8, -1],
#        [-6,  7],
#        [-8,  9],
#        [-7,  3],
#        [ 1,  3],
#        [-6,  7],
#        [-4,  5],
#        [-8,  0],
#        [ 7, -5]])})
# array[9, 2] i64 n=18 x∈[-8, 9] μ=0.278 σ=5.895
# OrderedDict({'X': array([[-6, -6],
#        [ 5, -8],
#        [ 1, -8]])})
# array[3, 2] i64 n=6 x∈[-8, 5] μ=-3.667 σ=4.922 [[-6, -6], [5, -8], [1, -8]]
# OrderedDict({'X': array([[ 4,  9],
#        [ 6,  1],
#        [-9, -9]])})
# array[3, 2] i64 n=6 x∈[-9, 9] μ=0.333 σ=7.016 [[4, 9], [6, 1], [-9, -9]]
# OrderedDict({'X': array([[ 3, -4],
#        [ 3, -4],
#        [ 9,  6],
#        [-7,  4],
#        [-8, -5],
#        [-3,  5],
#        [ 4, -7],
#        [-3, -3],
#        [ 9, -4]])})
# array[9, 2] i64 n=18 x∈[-8, 9] μ=-0.278 σ=5.445
# OrderedDict({'X': array([[ 9,  7],
#        [ 1, -7],
#        [ 3, -6]])})
# array[3, 2] i64 n=6 x∈[-7, 9] μ=1.167 σ=6.012 [[9, 7], [1, -7], [3, -6]]
# OrderedDict({'X': array([[ 9, -4],
#        [ 1,  4],
#        [ 8,  2],
#        [-7, -5],
#        [-3,  4],
#        [ 1, -1],
#        [ 1,  6]])})
# array[7, 2] i64 n=14 x∈[-7, 9] μ=1.143 σ=4.642
# OrderedDict({'X': array([[ -3,  -9],
#        [  8, -10],
#        [ -1,  -2],
#        [  8,   1],
#        [  9,   7],
#        [  5,  -7]])})
# array[6, 2] i64 n=12 x∈[-10, 9] μ=0.500 σ=6.614
# OrderedDict({'X': array([[ 4,  5],
#        [-9,  2],
#        [ 1, -3],
#        [ 1,  3]])})
# array[4, 2] i64 n=8 x∈[-9, 5] μ=0.500 σ=4.243 [[4, 5], [-9, 2], [1, -3], [1, 3]]
# OrderedDict({'X': array([[-9,  6],
#        [-9,  6],
#        [-9, -9],
#        [ 2, -4]])})
# array[4, 2] i64 n=8 x∈[-9, 6] μ=-3.250 σ=6.437 [[-9, 6], [-9, 6], [-9, -9], [2, -4]]
# OrderedDict({'X': array([[-2,  3],
#        [ 0,  9]])})
# array[2, 2] i64 n=4 x∈[-2, 9] μ=2.500 σ=4.153 [[-2, 3], [0, 9]]
# OrderedDict({'X': array([[-10,  -6],
#        [-10,  -5],
#        [  5,   9],
#        [  5,   9]])})
# array[4, 2] i64 n=8 x∈[-10, 9] μ=-0.375 σ=7.680 [[-10, -6], [-10, -5], [5, 9], [5, 9]]
# OrderedDict({'X': array([[ 2,  3],
#        [ 0, -1],
#        [ 6, -4]])})
# array[3, 2] i64 n=6 x∈[-4, 6] μ=1.000 σ=3.162 [[2, 3], [0, -1], [6, -4]]
# OrderedDict({'X': array([[ -7,   6],
#        [-10,  -9],
#        [  8, -10],
#        [  1,   8],
#        [  8,   5],
#        [  5,  -3],
#        [  2,   3]])})
# array[7, 2] i64 n=14 x∈[-10, 8] μ=0.500 σ=6.695
# OrderedDict({'X': array([[ 4,  4],
#        [-3,  2],
#        [ 1,  2],
#        [ 5,  1]])})
# array[4, 2] i64 n=8 x∈[-3, 5] μ=2.000 σ=2.345 [[4, 4], [-3, 2], [1, 2], [5, 1]]
# OrderedDict({'X': array([[  4,   8],
#        [ -6,  -9],
#        [  7,   7],
#        [  6,  -1],
#        [  6,  -8],
#        [  5,   7],
#        [ -4, -10]])})
# array[7, 2] i64 n=14 x∈[-10, 8] μ=0.857 σ=6.610
# OrderedDict({'X': array([[  2,   5],
#        [  0,  -8],
#        [ -2,  -4],
#        [ -8, -10],
#        [  0,   2],
#        [ -7,  -1],
#        [ -3,   6],
#        [  0,  -6]])})
# array[8, 2] i64 n=16 x∈[-10, 6] μ=-2.125 σ=4.608
# OrderedDict({'X': array([[-7, -5],
#        [-4,  1],
#        [-8, -3]])})
# array[3, 2] i64 n=6 x∈[-8, 1] μ=-4.333 σ=2.925 [[-7, -5], [-4, 1], [-8, -3]]
# OrderedDict({'X': array([[ -1, -10],
#        [  6,   7],
#        [ -2,   9],
#        [  5,   6],
#        [  7,   0]])})
# array[5, 2] i64 n=10 x∈[-10, 9] μ=2.700 σ=5.551 [[-1, -10], [6, 7], [-2, 9], [5, 6], [7, 0]]
# OrderedDict({'X': array([[-7, -3],
#        [-1, -7],
#        [-3,  6]])})
# array[3, 2] i64 n=6 x∈[-7, 6] μ=-2.500 σ=4.387 [[-7, -3], [-1, -7], [-3, 6]]
# OrderedDict({'X': array([[ -6,  -6],
#        [ -4, -10],
#        [  7,  -5],
#        [  9,   4]])})
# array[4, 2] i64 n=8 x∈[-10, 9] μ=-1.375 σ=6.556 [[-6, -6], [-4, -10], [7, -5], [9, 4]]
# OrderedDict({'X': array([[ -2,  -8],
#        [  7,   5],
#        [  6,  -2],
#        [  2,  -3],
#        [  2, -10]])})
# array[5, 2] i64 n=10 x∈[-10, 7] μ=-0.300 σ=5.460 [[-2, -8], [7, 5], [6, -2], [2, -3], [2, -10]]
# OrderedDict({'X': array([[  1,   1],
#        [ -2, -10],
#        [  3,   3],
#        [ -5,   5],
#        [ -3,   8],
#        [ -6,   4]])})
# array[6, 2] i64 n=12 x∈[-10, 8] μ=-0.083 σ=4.991
# OrderedDict({'X': array([[ -5,   6],
#        [ -6,  -1],
#        [ -6,   6],
#        [  8,  -5],
#        [  4,  -7],
#        [  6, -10]])})
# array[6, 2] i64 n=12 x∈[-10, 8] μ=-0.833 σ=6.135
# OrderedDict({'X': array([[-1,  8],
#        [-9,  6],
#        [ 7,  2]])})
# array[3, 2] i64 n=6 x∈[-9, 8] μ=2.167 σ=5.871 [[-1, 8], [-9, 6], [7, 2]]
# OrderedDict({'X': array([[ 9, -6],
#        [-7, -4],
#        [-6,  8],
#        [ 9, -4],
#        [ 2, -7],
#        [ 4,  9],
#        [ 7, -7],
#        [-7, -9]])})
# array[8, 2] i64 n=16 x∈[-9, 9] μ=-0.562 σ=6.855
# OrderedDict({'X': array([[  9,  -6],
#        [ -3,   0],
#        [  0,   7],
#        [  8,   6],
#        [-10,  -6],
#        [ -8,   3],
#        [ -9,  -8]])})
# array[7, 2] i64 n=14 x∈[-10, 9] μ=-1.214 σ=6.592
# OrderedDict({'X': array([[ 9,  2],
#        [-3,  3],
#        [ 7,  9],
#        [ 2,  7]])})
# array[4, 2] i64 n=8 x∈[-3, 9] μ=4.500 σ=3.937 [[9, 2], [-3, 3], [7, 9], [2, 7]]
# OrderedDict({'X': array([[-9, -6],
#        [ 0,  0]])})
# array[2, 2] i64 n=4 x∈[-9, 0] μ=-3.750 σ=3.897 [[-9, -6], [0, 0]]
# OrderedDict({'X': array([[-8, -9],
#        [ 3,  9]])})
# array[2, 2] i64 n=4 x∈[-9, 9] μ=-1.250 σ=7.562 [[-8, -9], [3, 9]]
# OrderedDict({'X': array([[ 7, -6],
#        [-3, -4],
#        [-1,  5],
#        [ 8,  0],
#        [ 8, -8],
#        [ 7, -7],
#        [ 9,  6],
#        [ 2, -7],
#        [ 3, -8]])})
# array[9, 2] i64 n=18 x∈[-8, 9] μ=0.611 σ=6.066

# %% [markdown]
# # Task 1. Vector lenghts
#
# - Write a function that calculates vector lengths, answer should return array of shape $2$
# - Apply this function to all the inputs

# %%
def get_lengths(X):
    res = np.sqrt((X**2).sum(axis=0))
    return res

# %%
answers['lengths'] = [
    get_lengths(**inp) for inp in inputs
]
answers['lengths']
# Out:
# [array([10.19803903,  8.60232527]),
#  array([14.52583905, 12.08304597]),
#  array([21.49418526, 18.41195264]),
#  array([10.86278049, 17.40689519]),
#  array([18.92088793, 18.30300522]),
#  array([11.61895004, 18.38477631]),
#  array([22.02271555, 18.57417562]),
#  array([13.49073756,  6.164414  ]),
#  array([15.03329638, 13.34166406]),
#  array([10.04987562,  6.244998  ]),
#  array([14.59451952, 14.73091986]),
#  array([12.04159458,  9.94987437]),
#  array([10.67707825, 14.76482306]),
#  array([12.12435565, 16.673332  ]),
#  array([16.40121947, 10.39230485]),
#  array([14.62873884, 17.77638883]),
#  array([15.16575089,  9.48683298]),
#  array([20.73644135, 12.60952021]),
#  array([17.63519209, 18.57417562]),
#  array([9.64365076, 9.64365076]),
#  array([16.55294536, 15.71623365]),
#  array([12.20655562, 12.36931688]),
#  array([ 9.8488578 , 10.19803903]),
#  array([19.39071943, 17.77638883]),
#  array([15.55634919, 19.94993734]),
#  array([11.13552873, 12.60952021]),
#  array([8.60232527, 4.47213595]),
#  array([ 7.34846923, 12.80624847]),
#  array([15.77973384, 17.69180601]),
#  array([12.        , 15.84297952]),
#  array([17.88854382, 13.49073756]),
#  array([17.17556404, 16.37070554]),
#  array([13.41640786, 15.09966887]),
#  array([11.48912529, 14.69693846]),
#  array([14.86606875, 18.08314132]),
#  array([15.55634919, 11.35781669]),
#  array([ 9.69535971, 11.74734012]),
#  array([17.72004515, 16.46207763]),
#  array([ 5.38516481, 10.90871211]),
#  array([17.3781472 , 12.84523258]),
#  array([15.39480432, 15.8113883 ]),
#  array([12.12435565, 15.42724862]),
#  array([12.40967365, 13.96424004]),
#  array([ 9.69535971, 11.78982612]),
#  array([11.22497216,  9.74679434]),
#  array([12.92284798, 13.85640646]),
#  array([11.04536102, 12.28820573]),
#  array([19.8242276 , 20.85665361]),
#  array([13.67479433, 11.35781669]),
#  array([16.4924225 , 11.13552873]),
#  array([13.        , 14.07124728]),
#  array([6.40312424, 6.32455532]),
#  array([13.19090596, 12.40967365]),
#  array([11.3137085 ,  3.60555128]),
#  array([ 8.77496439, 16.70329309]),
#  array([19.67231557, 16.97056275]),
#  array([19.10497317, 15.62049935]),
#  array([ 3.87298335, 17.34935157]),
#  array([6.78232998, 7.48331477]),
#  array([7.07106781, 7.07106781]),
#  array([14.07124728, 17.80449381]),
#  array([15.29705854, 16.37070554]),
#  array([12.16552506, 13.37908816]),
#  array([14.35270009, 17.91647287]),
#  array([16.76305461, 16.18641406]),
#  array([11.04536102,  8.71779789]),
#  array([13.56465997, 11.22497216]),
#  array([12.80624847, 17.80449381]),
#  array([5.09901951, 9.8488578 ]),
#  array([15.39480432, 17.17556404]),
#  array([10.48808848,  9.48683298]),
#  array([19.46792233, 15.74801575]),
#  array([ 7.87400787, 12.80624847]),
#  array([11.53256259, 12.76714533]),
#  array([18.08314132, 14.4222051 ]),
#  array([ 9.53939201, 11.5758369 ]),
#  array([14.35270009, 10.67707825]),
#  array([15.62049935, 16.85229955]),
#  array([9.94987437, 6.8556546 ]),
#  array([15.71623365, 13.        ]),
#  array([2.        , 9.48683298]),
#  array([15.8113883 , 14.93318452]),
#  array([6.32455532, 5.09901951]),
#  array([17.52141547, 18.        ]),
#  array([7.14142843, 5.        ]),
#  array([14.62873884, 20.19900988]),
#  array([11.40175425, 16.79285562]),
#  array([11.35781669,  5.91607978]),
#  array([10.72380529, 16.30950643]),
#  array([7.68114575, 9.69535971]),
#  array([13.49073756, 13.3041347 ]),
#  array([ 9.8488578, 14.2126704]),
#  array([ 9.16515139, 14.6628783 ]),
#  array([14.59451952, 15.71623365]),
#  array([11.44552314, 10.19803903]),
#  array([19.10497317, 19.79898987]),
#  array([19.97498436, 15.16575089]),
#  array([11.95826074, 11.95826074]),
#  array([9., 6.]),
#  array([ 8.54400375, 12.72792206]),
#  array([18.16590212, 18.41195264])]

# %% [markdown]
# # Task 2. Vector directions
#
# - Write a function that calculates vector directions. Result should be of the same shape as the original array X
# - Use $10^{-8}$ addition in division to avoid division by zero
# - Apply this function to all arrays in the inputs

# %%
def get_directions(X):
    res = None
    lenght = np.sqrt((X**2).sum(axis=0))
    res = X / lenght

    return res

# %%
answers['directions'] = [
    get_directions(**inp) for inp in inputs
]
answers['directions']
# Out:
# [array([[ 0.19611614,  0.58123819],
#         [-0.98058068, -0.81373347]]),
#  array([[-0.48189987, -0.24828177],
#         [-0.06884284,  0.7448453 ],
#         [ 0.55074271, -0.49656353],
#         [-0.27537136,  0.16552118],
#         [-0.61958555, -0.33104236]]),
#  array([[ 0.18609684,  0.38018781],
#         [-0.23262105,  0.16293763],
#         [-0.09304842, -0.05431254],
#         [ 0.41871789,  0.32587527],
#         [ 0.41871789, -0.27156272],
#         [ 0.23262105,  0.27156272],
#         [-0.46524211,  0.43450036],
#         [-0.32566947,  0.38018781],
#         [ 0.41871789,  0.4888129 ]]),
#  array([[ 0.36822985, -0.1723455 ],
#         [-0.92057462, -0.51703649],
#         [-0.09205746, -0.57448499],
#         [ 0.        , -0.40213949],
#         [ 0.09205746,  0.45958799]]),
#  array([[-0.42281314, -0.54635836],
#         [-0.52851642, -0.32781502],
#         [-0.26425821, -0.21854335],
#         [-0.10570328,  0.38245086],
#         [ 0.26425821, -0.32781502],
#         [-0.05285164,  0.        ],
#         [-0.47566478, -0.49172253],
#         [-0.15855493, -0.05463584],
#         [-0.3699615 , -0.21854335]]),
#  array([[ 0.0860663 ,  0.21757132],
#         [ 0.68853037, -0.54392829],
#         [ 0.34426519, -0.38074981],
#         [ 0.17213259,  0.        ],
#         [ 0.0860663 , -0.32635698],
#         [-0.34426519, -0.32635698],
#         [ 0.43033148, -0.38074981],
#         [ 0.17213259, -0.32635698],
#         [-0.17213259,  0.21757132]]),
#  array([[-0.31785363,  0.26919095],
#         [ 0.13622298,  0.32302914],
#         [ 0.31785363, -0.26919095],
#         [-0.04540766, -0.37686733],
#         [-0.45407661, -0.26919095],
#         [-0.45407661,  0.37686733],
#         [ 0.36326129, -0.32302914],
#         [-0.36326129,  0.32302914],
#         [-0.31785363, -0.43070552]]),
#  array([[ 0.22237479,  0.97332853],
#         [-0.22237479, -0.16222142],
#         [-0.74124932,  0.        ],
#         [ 0.59299945,  0.16222142]]),
#  array([[-0.53215208, -0.59962535],
#         [-0.46563307, -0.52467218],
#         [ 0.53215208,  0.29981268],
#         [-0.46563307,  0.52467218]]),
#  array([[ 0.39801488, -0.16012815],
#         [-0.89553347, -0.96076892],
#         [ 0.        ,  0.16012815],
#         [-0.19900744,  0.16012815]]),
#  array([[ 0.61666984,  0.40730654],
#         [-0.68518871, -0.67884423],
#         [-0.27407548,  0.61095981],
#         [ 0.27407548,  0.        ]]),
#  array([[-0.16609096,  0.30151134],
#         [-0.66436384, -0.70352647],
#         [-0.66436384,  0.10050378],
#         [ 0.24913644,  0.60302269],
#         [-0.16609096, -0.20100756]]),
#  array([[-0.18731716, -0.54182837],
#         [-0.65561007,  0.13545709],
#         [ 0.37463432, -0.67728546],
#         [-0.56195149, -0.47409982],
#         [ 0.28097574,  0.06772855]]),
#  array([[ 0.24743583,  0.17992804],
#         [ 0.08247861,  0.35985609],
#         [ 0.32991444,  0.35985609],
#         [ 0.74230749, -0.53978413],
#         [-0.16495722, -0.59976014],
#         [-0.49487166, -0.23990406]]),
#  array([[ 0.18291323, -0.28867513],
#         [ 0.30485538, -0.09622504],
#         [ 0.48776861, -0.19245009],
#         [ 0.30485538,  0.09622504],
#         [-0.2438843 ,  0.48112522],
#         [-0.54873968,  0.19245009],
#         [-0.42679753,  0.76980036]]),
#  array([[-0.47851015,  0.        ],
#         [ 0.13671719, -0.22501758],
#         [-0.47851015, -0.28127198],
#         [ 0.06835859, -0.56254395],
#         [ 0.06835859, -0.11250879],
#         [ 0.        ,  0.0562544 ],
#         [-0.34179296,  0.28127198],
#         [-0.13671719, -0.45003516],
#         [ 0.61522733,  0.50628956]]),
#  array([[-0.46156633, -0.73786479],
#         [-0.19781414, -0.10540926],
#         [-0.06593805, -0.10540926],
#         [-0.46156633,  0.42163702],
#         [ 0.52750438,  0.21081851],
#         [-0.46156633, -0.10540926],
#         [ 0.        ,  0.31622777],
#         [-0.19781414, -0.31622777]]),
#  array([[-0.43401854,  0.15861032],
#         [-0.38579426, -0.63444127],
#         [-0.43401854, -0.39652579],
#         [-0.09644856, -0.47583095],
#         [-0.48224282,  0.07930516],
#         [-0.38579426, -0.39652579],
#         [ 0.28934569, -0.15861032]]),
#  array([[-0.51034318,  0.37686733],
#         [ 0.34022879, -0.37686733],
#         [-0.1134096 , -0.32302914],
#         [ 0.34022879, -0.37686733],
#         [-0.17011439, -0.37686733],
#         [ 0.45363838,  0.37686733],
#         [-0.51034318,  0.43070552]]),
#  array([[-0.82956136, -0.51847585],
#         [-0.51847585,  0.20739034],
#         [ 0.20739034, -0.82956136]]),
#  array([[-0.18123663, -0.19088543],
#         [ 0.06041221,  0.44539933],
#         [-0.24164884, -0.19088543],
#         [ 0.48329767,  0.06362848],
#         [ 0.54370988,  0.44539933],
#         [-0.06041221,  0.25451391],
#         [-0.06041221,  0.50902781],
#         [-0.60412209, -0.06362848],
#         [ 0.06041221,  0.44539933]]),
#  array([[-0.81923192,  0.48507125],
#         [ 0.        , -0.48507125],
#         [-0.57346234,  0.72760688]]),
#  array([[ 0.40613847, -0.98058068],
#         [ 0.91381155, -0.19611614]]),
#  array([[ 0.15471319,  0.39378077],
#         [-0.51571062,  0.0562544 ],
#         [-0.30942637, -0.56254395],
#         [ 0.        ,  0.22501758],
#         [ 0.4125685 , -0.33752637],
#         [-0.36099744,  0.50628956],
#         [-0.15471319, -0.11250879],
#         [ 0.15471319, -0.28127198],
#         [-0.51571062, -0.11250879]]),
#  array([[ 0.32141217,  0.05012547],
#         [-0.38569461, -0.15037641],
#         [ 0.1928473 ,  0.        ],
#         [ 0.25712974,  0.35087829],
#         [ 0.57854191, -0.35087829],
#         [-0.06428243,  0.40100377],
#         [-0.51425948,  0.45112924],
#         [ 0.06428243,  0.40100377],
#         [ 0.1928473 , -0.45112924]]),
#  array([[ 0.        ,  0.47583095],
#         [ 0.53881591, -0.55513611],
#         [ 0.62861856,  0.        ],
#         [-0.08980265,  0.15861032],
#         [ 0.26940795, -0.31722063],
#         [-0.3592106 , -0.23791548],
#         [-0.1796053 ,  0.23791548],
#         [-0.26940795,  0.47583095]]),
#  array([[ 0.58123819, -0.4472136 ],
#         [-0.81373347, -0.89442719]]),
#  array([[-0.40824829, -0.62469505],
#         [ 0.81649658,  0.62469505],
#         [ 0.40824829, -0.46852129]]),
#  array([[ 0.12674485,  0.39566339],
#         [-0.57035183, -0.28261671],
#         [-0.57035183,  0.50871008],
#         [ 0.57035183, -0.16957003],
#         [-0.06337243,  0.39566339],
#         [-0.06337243, -0.56523342]]),
#  array([[-0.5       ,  0.44183608],
#         [ 0.5       , -0.44183608],
#         [ 0.        , -0.56807496],
#         [-0.5       , -0.37871664],
#         [ 0.5       ,  0.37871664]]),
#  array([[ 0.        ,  0.22237479],
#         [-0.1118034 ,  0.07412493],
#         [-0.2236068 , -0.07412493],
#         [ 0.2795085 , -0.51887452],
#         [ 0.50311529,  0.14824986],
#         [ 0.4472136 ,  0.51887452],
#         [ 0.        , -0.59299945],
#         [-0.50311529,  0.07412493],
#         [-0.3913119 ,  0.14824986]]),
#  array([[-0.52400026,  0.42759306],
#         [-0.58222251, -0.18325417],
#         [-0.34933351, -0.42759306],
#         [-0.29111125, -0.24433889],
#         [-0.40755576, -0.48867778],
#         [-0.1164445 , -0.5497625 ]]),
#  array([[-0.4472136 , -0.66226618],
#         [ 0.2236068 ,  0.59603956],
#         [-0.0745356 , -0.33113309],
#         [-0.67082039, -0.19867985],
#         [-0.1490712 , -0.19867985],
#         [-0.52174919,  0.13245324]]),
#  array([[-0.34815531, -0.20412415],
#         [ 0.78334945, -0.68041382],
#         [-0.43519414,  0.06804138],
#         [-0.08703883,  0.61237244],
#         [-0.26111648, -0.34020691]]),
#  array([[-0.13453456,  0.05530013],
#         [ 0.26906912, -0.55300126],
#         [-0.13453456,  0.49770114],
#         [-0.26906912,  0.        ],
#         [ 0.60540551, -0.44240101],
#         [-0.67267279,  0.49770114]]),
#  array([[ 0.25712974, -0.88045091],
#         [ 0.57854191, -0.35218036],
#         [-0.57854191,  0.17609018],
#         [ 0.51425948,  0.26413527]]),
#  array([[-0.61885275,  0.59587957],
#         [-0.72199487, -0.68100522],
#         [ 0.30942637,  0.42562827]]),
#  array([[-0.33859959, -0.06074567],
#         [-0.33859959,  0.42521972],
#         [ 0.45146612,  0.18223702],
#         [ 0.16929979, -0.48596539],
#         [-0.39503285, -0.06074567],
#         [ 0.11286653,  0.30372837],
#         [-0.45146612,  0.54671107],
#         [-0.22573306,  0.2429827 ],
#         [ 0.33859959,  0.30372837]]),
#  array([[-0.37139068, -0.9166985 ],
#         [ 0.        ,  0.09166985],
#         [ 0.55708601, -0.27500955],
#         [-0.74278135,  0.27500955]]),
#  array([[ 0.28771767, -0.07784989],
#         [-0.23017414,  0.07784989],
#         [ 0.46034827, -0.23354968],
#         [-0.5178918 , -0.07784989],
#         [-0.46034827,  0.62279916],
#         [ 0.23017414, -0.38924947],
#         [-0.3452612 ,  0.62279916]]),
#  array([[ 0.25982792,  0.50596443],
#         [-0.58461282,  0.12649111],
#         [-0.6495698 , -0.06324555],
#         [ 0.38974188, -0.50596443],
#         [-0.12991396,  0.56920998],
#         [ 0.        ,  0.37947332]]),
#  array([[-0.74230749, -0.64820372],
#         [-0.41239305, -0.51856298],
#         [ 0.41239305, -0.45374261],
#         [ 0.32991444, -0.32410186]]),
#  array([[ 0.72524067, -0.28644595],
#         [-0.32232919,  0.64450339],
#         [-0.32232919, -0.5728919 ],
#         [-0.32232919, -0.35805744],
#         [-0.40291148,  0.21483446]]),
#  array([[-0.61885275,  0.25445668],
#         [ 0.72199487, -0.59373225],
#         [ 0.30942637,  0.76337004]]),
#  array([[-0.17817416,  0.30779351],
#         [-0.4454354 ,  0.61558701],
#         [ 0.35634832, -0.51298918],
#         [-0.80178373, -0.51298918]]),
#  array([[ 0.15476465,  0.        ],
#         [ 0.30952929, -0.14433757],
#         [-0.23214697,  0.21650635],
#         [-0.38691162,  0.36084392],
#         [ 0.        , -0.50518149],
#         [ 0.        ,  0.57735027],
#         [-0.54167626,  0.28867513],
#         [ 0.61905859, -0.36084392]]),
#  array([[-0.54321448,  0.56965192],
#         [-0.45267873, -0.56965192],
#         [-0.45267873, -0.16275769],
#         [-0.54321448,  0.56965192]]),
#  array([[-0.45398995,  0.38357064],
#         [-0.45398995,  0.19178532],
#         [ 0.35310329, -0.14383899],
#         [ 0.05044333,  0.19178532],
#         [ 0.30265996, -0.43151697],
#         [ 0.35310329,  0.09589266],
#         [ 0.20177331, -0.4794633 ],
#         [-0.40354662,  0.43151697],
#         [ 0.20177331,  0.38357064]]),
#  array([[-0.07312724,  0.35218036],
#         [-0.73127242,  0.17609018],
#         [-0.07312724,  0.70436073],
#         [-0.43876345, -0.26413527],
#         [-0.5118907 ,  0.52827054]]),
#  array([[-0.30316953,  0.26940795],
#         [ 0.36380344,  0.26940795],
#         [ 0.48507125,  0.80822386],
#         [ 0.42443734, -0.26940795],
#         [ 0.42443734,  0.3592106 ],
#         [-0.42443734,  0.        ]]),
#  array([[ 0.        , -0.63960215],
#         [ 0.46153846,  0.        ],
#         [ 0.61538462,  0.42640143],
#         [-0.61538462, -0.28426762],
#         [-0.07692308, -0.56853524],
#         [ 0.15384615, -0.07106691]]),
#  array([[-0.93704257, -0.9486833 ],
#         [-0.15617376,  0.        ],
#         [ 0.31234752, -0.31622777]]),
#  array([[-0.37904902, -0.24174689],
#         [-0.75809804, -0.72524067],
#         [-0.53066863,  0.64465837]]),
#  array([[ 0.70710678, -0.5547002 ],
#         [ 0.70710678, -0.83205029]]),
#  array([[ 0.91168461, -0.41907904],
#         [ 0.22792115,  0.53881591],
#         [ 0.34188173, -0.59868434],
#         [ 0.        , -0.41907904]]),
#  array([[-0.35583   , -0.23570226],
#         [ 0.45749571, -0.47140452],
#         [ 0.40666285,  0.47140452],
#         [-0.20333143,  0.05892557],
#         [-0.50832857, -0.35355339],
#         [ 0.15249857, -0.05892557],
#         [-0.40666285, -0.53033009],
#         [ 0.10166571,  0.29462783]]),
#  array([[-0.47108153,  0.12803688],
#         [-0.26171196, -0.25607376],
#         [-0.47108153,  0.        ],
#         [-0.20936957, -0.25607376],
#         [-0.20936957, -0.25607376],
#         [ 0.05234239,  0.51214752],
#         [ 0.41873914,  0.51214752],
#         [ 0.47108153, -0.51214752]]),
#  array([[-0.25819889,  0.51875138],
#         [-0.51639778, -0.28819521],
#         [ 0.25819889, -0.51875138],
#         [ 0.25819889,  0.28819521],
#         [ 0.51639778,  0.28819521],
#         [ 0.51639778,  0.46111233]]),
#  array([[ 0.44232587,  0.26726124],
#         [-0.14744196, -0.53452248],
#         [-0.88465174,  0.80178373]]),
#  array([[-0.70710678,  0.70710678],
#         [-0.70710678, -0.70710678]]),
#  array([[ 0.49746834, -0.56165596],
#         [ 0.42640143,  0.33699357],
#         [-0.71066905,  0.        ],
#         [ 0.14213381, -0.56165596],
#         [-0.21320072,  0.50549036]]),
#  array([[-0.39223227,  0.5497625 ],
#         [-0.39223227, -0.30542361],
#         [ 0.13074409,  0.42759306],
#         [ 0.58834841,  0.12216944],
#         [-0.26148818, -0.18325417],
#         [ 0.39223227, -0.61084722],
#         [ 0.32686023,  0.        ]]),
#  array([[-0.57539646, -0.52320456],
#         [ 0.49319696,  0.44846106],
#         [-0.08219949, -0.37371755],
#         [ 0.49319696,  0.52320456],
#         [-0.08219949,  0.14948702],
#         [ 0.41099747, -0.29897404]]),
#  array([[-0.62705971, -0.33488734],
#         [ 0.41803981, -0.33488734],
#         [-0.2090199 ,  0.22325823],
#         [-0.2090199 , -0.44651646],
#         [ 0.41803981,  0.27907279],
#         [ 0.34836651,  0.44651646],
#         [ 0.0696733 ,  0.22325823],
#         [-0.2090199 , -0.44651646]]),
#  array([[ 0.41758499, -0.43246144],
#         [-0.178965  ,  0.18534062],
#         [ 0.35792999, -0.30890103],
#         [-0.35792999,  0.18534062],
#         [-0.29827499,  0.55602186],
#         [ 0.059655  , -0.12356041],
#         [-0.59654999,  0.43246144],
#         [-0.29827499, -0.37068124]]),
#  array([[-0.45267873,  0.6882472 ],
#         [-0.36214298, -0.22941573],
#         [ 0.81482171, -0.6882472 ]]),
#  array([[ 0.        ,  0.        ],
#         [-0.51604685, -0.4454354 ],
#         [-0.07372098, -0.17817416],
#         [ 0.51604685,  0.80178373],
#         [-0.14744196,  0.        ],
#         [-0.6634888 ,  0.35634832]]),
#  array([[ 0.46852129, -0.39315917],
#         [-0.23426064, -0.50549036],
#         [-0.15617376, -0.56165596],
#         [-0.3904344 ,  0.28082798],
#         [-0.31234752,  0.28082798],
#         [-0.3904344 , -0.0561656 ],
#         [ 0.54660817,  0.33699357]]),
#  array([[ 0.19611614,  0.40613847],
#         [-0.98058068,  0.91381155]]),
#  array([[ 0.19487094,  0.05822225],
#         [ 0.06495698, -0.52400026],
#         [-0.19487094,  0.34933351],
#         [-0.19487094,  0.29111125],
#         [-0.6495698 , -0.34933351],
#         [ 0.51965584, -0.46577801],
#         [-0.12991396,  0.        ],
#         [-0.3247849 , -0.232889  ],
#         [-0.25982792, -0.34933351]]),
#  array([[-0.57207755, -0.52704628],
#         [-0.47673129, -0.42163702],
#         [-0.66742381,  0.73786479]]),
#  array([[ 0.4109324 , -0.06350006],
#         [-0.3081993 ,  0.44450044],
#         [-0.4109324 ,  0.57150057],
#         [-0.35956585,  0.19050019],
#         [ 0.05136655,  0.19050019],
#         [-0.3081993 ,  0.44450044],
#         [-0.2054662 ,  0.31750032],
#         [-0.4109324 ,  0.        ],
#         [ 0.35956585, -0.31750032]]),
#  array([[-0.76200076, -0.46852129],
#         [ 0.63500064, -0.62469505],
#         [ 0.12700013, -0.62469505]]),
#  array([[ 0.34684399,  0.7049344 ],
#         [ 0.52026598,  0.07832604],
#         [-0.78039897, -0.7049344 ]]),
#  array([[ 0.16590038, -0.2773501 ],
#         [ 0.16590038, -0.2773501 ],
#         [ 0.49770114,  0.41602515],
#         [-0.38710088,  0.2773501 ],
#         [-0.44240101, -0.34668762],
#         [-0.16590038,  0.34668762],
#         [ 0.22120051, -0.48536267],
#         [-0.16590038, -0.20801257],
#         [ 0.49770114, -0.2773501 ]]),
#  array([[ 0.94345635,  0.6047079 ],
#         [ 0.10482848, -0.6047079 ],
#         [ 0.31448545, -0.51832106]]),
#  array([[ 0.62705971, -0.37463432],
#         [ 0.0696733 ,  0.37463432],
#         [ 0.55738641,  0.18731716],
#         [-0.48771311, -0.46829291],
#         [-0.2090199 ,  0.37463432],
#         [ 0.0696733 , -0.09365858],
#         [ 0.0696733 ,  0.56195149]]),
#  array([[-0.19205532, -0.53405175],
#         [ 0.51214752, -0.59339083],
#         [-0.06401844, -0.11867817],
#         [ 0.51214752,  0.05933908],
#         [ 0.57616596,  0.41537358],
#         [ 0.3200922 , -0.41537358]]),
#  array([[ 0.40201513,  0.72932496],
#         [-0.90453403,  0.29172998],
#         [ 0.10050378, -0.43759497],
#         [ 0.10050378,  0.43759497]]),
#  array([[-0.57265629,  0.46153846],
#         [-0.57265629,  0.46153846],
#         [-0.57265629, -0.69230769],
#         [ 0.12725695, -0.30769231]]),
#  array([[-1.        ,  0.31622777],
#         [ 0.        ,  0.9486833 ]]),
#  array([[-0.63245553, -0.40178972],
#         [-0.63245553, -0.33482477],
#         [ 0.31622777,  0.60268458],
#         [ 0.31622777,  0.60268458]]),
#  array([[ 0.31622777,  0.58834841],
#         [ 0.        , -0.19611614],
#         [ 0.9486833 , -0.78446454]]),
#  array([[-0.3995111 ,  0.33333333],
#         [-0.57073015, -0.5       ],
#         [ 0.45658412, -0.55555556],
#         [ 0.05707301,  0.44444444],
#         [ 0.45658412,  0.27777778],
#         [ 0.28536507, -0.16666667],
#         [ 0.11414603,  0.16666667]]),
#  array([[ 0.56011203,  0.8       ],
#         [-0.42008403,  0.4       ],
#         [ 0.14002801,  0.4       ],
#         [ 0.70014004,  0.2       ]]),
#  array([[ 0.27343437,  0.39605902],
#         [-0.41015156, -0.44556639],
#         [ 0.47851015,  0.34655164],
#         [ 0.41015156, -0.04950738],
#         [ 0.41015156, -0.39605902],
#         [ 0.34179296,  0.34655164],
#         [-0.27343437, -0.49507377]]),
#  array([[ 0.1754116 ,  0.29774567],
#         [ 0.        , -0.47639307],
#         [-0.1754116 , -0.23819653],
#         [-0.70164642, -0.59549133],
#         [ 0.        ,  0.11909827],
#         [-0.61394061, -0.05954913],
#         [-0.26311741,  0.3572948 ],
#         [ 0.        , -0.3572948 ]]),
#  array([[-0.61631563, -0.84515425],
#         [-0.35218036,  0.16903085],
#         [-0.70436073, -0.50709255]]),
#  array([[-0.09325048, -0.61313934],
#         [ 0.55950288,  0.42919754],
#         [-0.18650096,  0.55182541],
#         [ 0.4662524 ,  0.3678836 ],
#         [ 0.65275337,  0.        ]]),
#  array([[-0.91132238, -0.30942637],
#         [-0.13018891, -0.72199487],
#         [-0.39056673,  0.61885275]]),
#  array([[-0.44474959, -0.45098762],
#         [-0.29649973, -0.75164603],
#         [ 0.51887452, -0.37582301],
#         [ 0.66712438,  0.30065841]]),
#  array([[-0.20306923, -0.56287804],
#         [ 0.71074232,  0.35179877],
#         [ 0.6092077 , -0.14071951],
#         [ 0.20306923, -0.21107926],
#         [ 0.20306923, -0.70359754]]),
#  array([[ 0.10910895,  0.06819943],
#         [-0.21821789, -0.68199434],
#         [ 0.32732684,  0.2045983 ],
#         [-0.54554473,  0.34099717],
#         [-0.32732684,  0.54559547],
#         [-0.65465367,  0.27279774]]),
#  array([[-0.34259435,  0.38177086],
#         [-0.41111323, -0.06362848],
#         [-0.41111323,  0.38177086],
#         [ 0.54815097, -0.31814238],
#         [ 0.27407548, -0.44539933],
#         [ 0.41111323, -0.63628476]]),
#  array([[-0.08737041,  0.78446454],
#         [-0.78633365,  0.58834841],
#         [ 0.61159284,  0.19611614]]),
#  array([[ 0.47108153, -0.30304576],
#         [-0.36639675, -0.20203051],
#         [-0.31405435,  0.40406102],
#         [ 0.47108153, -0.20203051],
#         [ 0.10468478, -0.35355339],
#         [ 0.20936957,  0.45456865],
#         [ 0.36639675, -0.35355339],
#         [-0.36639675, -0.45456865]]),
#  array([[ 0.45056356, -0.39562828],
#         [-0.15018785,  0.        ],
#         [ 0.        ,  0.46156633],
#         [ 0.40050094,  0.39562828],
#         [-0.50062617, -0.39562828],
#         [-0.40050094,  0.19781414],
#         [-0.45056356, -0.52750438]]),
#  array([[ 0.75261781,  0.1672484 ],
#         [-0.2508726 ,  0.2508726 ],
#         [ 0.58536941,  0.75261781],
#         [ 0.1672484 ,  0.58536941]]),
#  array([[-1., -1.],
#         [ 0.,  0.]]),
#  array([[-0.93632918, -0.70710678],
#         [ 0.35112344,  0.70710678]]),
#  array([[ 0.38533732, -0.32587527],
#         [-0.16514456, -0.21725018],
#         [-0.05504819,  0.27156272],
#         [ 0.44038551,  0.        ],
#         [ 0.44038551, -0.43450036],
#         [ 0.38533732, -0.38018781],
#         [ 0.49543369,  0.32587527],
#         [ 0.11009638, -0.38018781],
#         [ 0.16514456, -0.43450036]])]

# %% [markdown]
# # Step 3. Visualization
#
# We will visualize vectors and directions using `matplotlib`

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
ax = plt.gca()
X = inputs[0]['X']
vecs = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*vecs)

print(X, Y, U, V)

ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'red')

X = answers['directions'][0] * 2
norms = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*norms)

print(X, Y, U, V)
ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'blue')
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
plt.draw()
plt.grid()
plt.legend(['original', 'normalized'])
plt.show()
# Out:
# (0, 0) (0, 0) (2, 5) (-10, -7)
# (0.0, 0.0) (0.0, 0.0) (0.3922322702763681, 1.162476387438193) (-1.9611613513818404, -1.62746694241347)

# %% [markdown]
# # Task 4. Scalar Product
#
# Write a function that calculates
# - cosine distance between the vectors
# - use $10^{-8}$ additional constant in the denominator for the sake of numerical stability

# %%
def get_cosine(X):
    res = None
    ## YOUR CODE HERE
    return res

# %%
answers['cosine'] = [
    get_cosine(**inp) for inp in inputs
]

# %%
print(answers['cosine'][0])
# Out:
# None

# %% [markdown]
# # Task 5. Orthonormalization
#
# Create a pair of orthonormal vectors
# - Take the first vector and normalize it
# - Take the second vector, remove the collinear component to the first one
# - Normalize it

# %%
def get_orthonormal(X):
    res = X.copy().astype('float32')
    ## YOUR CODE HERE
    return res

# %%
answers['orthonormal'] = [
    get_orthonormal(**inp) for inp in inputs
]

# %% [markdown]
# # 6. Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
ax = plt.gca()
X = inputs[0]['X']
print(X)
vecs = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*vecs)
ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'red')

X = answers['orthonormal'][0]
print(X)
norms = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*norms)
ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'blue')
ax.set_xlim([-5, 5])
ax.set_ylim([-5, 5])
plt.draw()
plt.grid()
plt.legend(['original', 'orthonormalized'])
plt.show()
# Out:
# [[  2   5]
#  [-10  -7]]
# [[  2.   5.]
#  [-10.  -7.]]

# %% [markdown]
# # 7. Saving the answer

# %%
json_tricks.dump(answers, '.answer.json')
# Out:
# '{"lengths": [{"__ndarray__": [10.198039027185569, 8.602325267042627], "dtype": "float64", "shape": [2]}, {"__ndarray__": [14.52583904633395, 12.083045973594572], "dtype": "float64", "shape": [2]}, {"__ndarray__": [21.494185260204677, 18.411952639521967], "dtype": "float64", "shape": [2]}, {"__ndarray__": [10.862780491200215, 17.406895185529212], "dtype": "float64", "shape": [2]}, {"__ndarray__": [18.920887928424502, 18.303005217723125], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.61895003862225, 18.384776310850235], "dtype": "float64", "shape": [2]}, {"__ndarray__": [22.02271554554524, 18.57417562100671], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.490737563232042, 6.164414002968976], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.033296378372908, 13.341664064126334], "dtype": "float64", "shape": [2]}, {"__ndarray__": [10.04987562112089, 6.244997998398398], "dtype": "float64", "shape": [2]}, {"__ndarray__": [14.594519519326424, 14.730919862656235], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.041594578792296, 9.9498743710662], "dtype": "float64", "shape": [2]}, {"__ndarray__": [10.677078252031311, 14.7648230602334], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.12435565298214, 16.673332000533065], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.401219466856727, 10.392304845413264], "dtype": "float64", "shape": [2]}, {"__ndarray__": [14.628738838327793, 17.776388834631177], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.165750888103101, 9.486832980505138], "dtype": "float64", "shape": [2]}, {"__ndarray__": [20.73644135332772, 12.609520212918492], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.635192088548397, 18.57417562100671], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.643650760992955, 9.643650760992955], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.55294535724685, 15.716233645501712], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.206555615733702, 12.36931687685298], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.848857801796104, 10.198039027185569], "dtype": "float64", "shape": [2]}, {"__ndarray__": [19.390719429665317, 17.776388834631177], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.556349186104045, 19.949937343260004], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.135528725660043, 12.609520212918492], "dtype": "float64", "shape": [2]}, {"__ndarray__": [8.602325267042627, 4.47213595499958], "dtype": "float64", "shape": [2]}, {"__ndarray__": [7.3484692283495345, 12.806248474865697], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.7797338380595, 17.69180601295413], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.0, 15.84297951775486], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.88854381999832, 13.490737563232042], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.175564037317667, 16.3707055437449], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.416407864998739, 15.0996688705415], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.489125293076057, 14.696938456699069], "dtype": "float64", "shape": [2]}, {"__ndarray__": [14.866068747318506, 18.083141320025124], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.556349186104045, 11.357816691600547], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.695359714832659, 11.74734012447073], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.72004514666935, 16.46207763315433], "dtype": "float64", "shape": [2]}, {"__ndarray__": [5.385164807134504, 10.908712114635714], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.378147196982766, 12.84523257866513], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.394804318340652, 15.811388300841896], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.12435565298214, 15.427248620541512], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.409673645990857, 13.96424004376894], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.695359714832659, 11.7898 ...
