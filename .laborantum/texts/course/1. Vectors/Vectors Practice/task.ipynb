# %% [markdown]
# # Vectors Practice

# %% [markdown]
# In this chapter we will work with vectors and code Gramm-Schmidt Orthonormalization Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
import lovely_numpy as ln
import json_tricks

# %%
inputs = json_tricks.load('inputs.json')
inputs1 = json_tricks.load('inputs2.json')

answers = {}

# %% [markdown]
# In your input you have arrys of shape $N \times 2$, which means that you have 2 vectors both having N coordinates

# %%
for one_input in inputs:
    print(one_input)
    print(ln.lovely(one_input['X']))
# Out:
# OrderedDict([('X', array([[1, 2],
#        [3, 4]]))])
# array[2, 2] i64 n=4 x∈[1, 4] μ=2.500 σ=1.118 [[1, 2], [3, 4]]
# OrderedDict([('X', array([[  4,   0],
#        [ -3,  -4],
#        [  8,   0],
#        [  0,  -7],
#        [ -3,  -8],
#        [ -9,   1],
#        [ -5,  -9],
#        [-10,   1]]))])
# array[8, 2] i64 n=16 x∈[-10, 8] μ=-2.750 σ=4.969
# OrderedDict([('X', array([[-7,  3],
#        [ 5,  4],
#        [-3,  3]]))])
# array[3, 2] i64 n=6 x∈[-7, 5] μ=0.833 σ=4.337 [[-7, 3], [5, 4], [-3, 3]]
# OrderedDict([('X', array([[ -4,  -2],
#        [-10,   1]]))])
# array[2, 2] i64 n=4 x∈[-10, 1] μ=-3.750 σ=4.023 [[-4, -2], [-10, 1]]
# OrderedDict([('X', array([[ -8, -10],
#        [ -6,  -1],
#        [ -4,  -2],
#        [ -4,  -2],
#        [ -3,   1],
#        [ -9, -10],
#        [  5,  -6],
#        [ -8,   1],
#        [ -3,  -8]]))])
# array[9, 2] i64 n=18 x∈[-10, 5] μ=-4.278 σ=4.093
# OrderedDict([('X', array([[  0,  -4],
#        [-10, -10],
#        [  9,   2],
#        [ -2,  -8],
#        [ -4,  -5],
#        [ -3,  -2],
#        [ -6, -10]]))])
# array[7, 2] i64 n=14 x∈[-10, 9] μ=-3.786 σ=5.059
# OrderedDict([('X', array([[  9,  -2],
#        [-10,  -3],
#        [ -4,   7],
#        [ -3, -10],
#        [  0,   7],
#        [ -1,  -8],
#        [ -4,   5],
#        [  5,   9],
#        [  6,  -9]]))])
# array[9, 2] i64 n=18 x∈[-10, 9] μ=-0.333 σ=6.429
# OrderedDict([('X', array([[ -8, -10],
#        [  9, -10],
#        [ -8,   7],
#        [ -1,  -8],
#        [ -3,   3],
#        [  7,   4]]))])
# array[6, 2] i64 n=12 x∈[-10, 9] μ=-1.500 σ=6.946
# OrderedDict([('X', array([[  9,   5],
#        [  2,   7],
#        [ -1,   8],
#        [  6,   8],
#        [ -6,  -2],
#        [  1, -10],
#        [-10,   4],
#        [ -9,   5]]))])
# array[8, 2] i64 n=16 x∈[-10, 9] μ=1.062 σ=6.466
# OrderedDict([('X', array([[ 7,  2],
#        [ 0, -7],
#        [-7, -1]]))])
# array[3, 2] i64 n=6 x∈[-7, 7] μ=-1.000 σ=4.933 [[7, 2], [0, -7], [-7, -1]]
# OrderedDict([('X', array([[ 5,  2],
#        [ 8,  6],
#        [-7,  1],
#        [-2,  8],
#        [ 1, -2],
#        [-4,  3],
#        [ 9,  8]]))])
# array[7, 2] i64 n=14 x∈[-7, 9] μ=2.571 σ=4.851
# OrderedDict([('X', array([[ -3,   5],
#        [  2, -10],
#        [  9,   6],
#        [ -4,   2],
#        [ -7,  -7],
#        [ -5,   8],
#        [  1,  -4]]))])
# array[7, 2] i64 n=14 x∈[-10, 9] μ=-0.500 σ=5.828
# OrderedDict([('X', array([[  7,   4],
#        [ -2,   6],
#        [  3,   4],
#        [-10,  -8],
#        [  5,   0]]))])
# array[5, 2] i64 n=10 x∈[-10, 7] μ=0.900 σ=5.576 [[7, 4], [-2, 6], [3, 4], [-10, -8], [5, 0]]
# OrderedDict([('X', array([[ -6,  -2],
#        [ -7,   6],
#        [ -2, -10],
#        [  9,   2],
#        [  5,   2]]))])
# array[5, 2] i64 n=10 x∈[-10, 9] μ=-0.300 σ=5.849 [[-6, -2], [-7, 6], [-2, -10], [9, 2], [5, 2]]
# OrderedDict([('X', array([[-5,  6],
#        [-6, -6],
#        [-5, -8],
#        [-6, -6],
#        [-1, -1],
#        [ 8,  6]]))])
# array[6, 2] i64 n=12 x∈[-8, 8] μ=-2.000 σ=5.385
# OrderedDict([('X', array([[-9, -5],
#        [-9,  2],
#        [ 0,  0],
#        [ 5,  0],
#        [ 8,  4],
#        [ 5,  0],
#        [ 5, -3],
#        [-7, -3],
#        [-7, -8]]))])
# array[9, 2] i64 n=18 x∈[-9, 8] μ=-1.222 σ=5.266
# OrderedDict([('X', array([[ 1,  6],
#        [ 2,  9],
#        [-7, -1],
#        [-8, -2],
#        [ 2,  7],
#        [ 4, -7],
#        [ 4, -9]]))])
# array[7, 2] i64 n=14 x∈[-9, 9] μ=0.071 σ=5.700
# OrderedDict([('X', array([[-2, -8],
#        [ 8, -3],
#        [-6, -7],
#        [-5, -9],
#        [ 9,  0],
#        [-7,  4],
#        [-5,  6]]))])
# array[7, 2] i64 n=14 x∈[-9, 9] μ=-1.786 σ=5.942
# OrderedDict([('X', array([[  6,  -6],
#        [  1,   7],
#        [  3,   0],
#        [ -2,  -9],
#        [  1,  -8],
#        [ -8, -10],
#        [ -3,  -3]]))])
# array[7, 2] i64 n=14 x∈[-10, 7] μ=-2.214 σ=5.307
# OrderedDict([('X', array([[-5,  2],
#        [ 4, -7]]))])
# array[2, 2] i64 n=4 x∈[-7, 4] μ=-1.500 σ=4.610 [[-5, 2], [4, -7]]
# OrderedDict([('X', array([[-6,  9],
#        [ 0, -1],
#        [-3, -5]]))])
# array[3, 2] i64 n=6 x∈[-6, 9] μ=-1.000 σ=4.933 [[-6, 9], [0, -1], [-3, -5]]
# OrderedDict([('X', array([[ 1,  1],
#        [-7,  5],
#        [-7, -6],
#        [-6, -3],
#        [-1,  6]]))])
# array[5, 2] i64 n=10 x∈[-7, 6] μ=-1.700 σ=4.627 [[1, 1], [-7, 5], [-7, -6], [-6, -3], [-1, 6]]
# OrderedDict([('X', array([[-2, -8],
#        [ 9,  0]]))])
# array[2, 2] i64 n=4 x∈[-8, 9] μ=-0.250 σ=6.098 [[-2, -8], [9, 0]]
# OrderedDict([('X', array([[-10,   6],
#        [  0,   7],
#        [  6,  -4],
#        [  6,   9],
#        [ -2,   6],
#        [  9,  -3]]))])
# array[6, 2] i64 n=12 x∈[-10, 9] μ=2.500 σ=5.838
# OrderedDict([('X', array([[  3,   5],
#        [  7,  -4],
#        [ -1,  -4],
#        [-10,   8],
#        [  5,   8],
#        [ -7,   7]]))])
# array[6, 2] i64 n=12 x∈[-10, 8] μ=1.417 σ=6.075
# OrderedDict([('X', array([[-1, -7],
#        [-2, -5],
#        [-9,  6]]))])
# array[3, 2] i64 n=6 x∈[-9, 6] μ=-3.000 σ=4.865 [[-1, -7], [-2, -5], [-9, 6]]
# OrderedDict([('X', array([[ -9,   4],
#        [ -6, -10],
#        [ -7,   4],
#        [  9,   8]]))])
# array[4, 2] i64 n=8 x∈[-10, 9] μ=-0.875 σ=7.390 [[-9, 4], [-6, -10], [-7, 4], [9, 8]]
# OrderedDict([('X', array([[ 1,  6],
#        [ 6, -1],
#        [ 6,  4],
#        [ 1,  5]]))])
# array[4, 2] i64 n=8 x∈[-1, 6] μ=3.500 σ=2.598 [[1, 6], [6, -1], [6, 4], [1, 5]]
# OrderedDict([('X', array([[ 7,  9],
#        [-4, -8],
#        [ 7, -1],
#        [-4,  6],
#        [ 3, -8],
#        [ 1,  2],
#        [-9, -8],
#        [-6,  0],
#        [-3,  1]]))])
# array[9, 2] i64 n=18 x∈[-9, 9] μ=-0.833 σ=5.620
# OrderedDict([('X', array([[ -4,   9],
#        [ -6, -10]]))])
# array[2, 2] i64 n=4 x∈[-10, 9] μ=-2.750 σ=7.120 [[-4, 9], [-6, -10]]
# OrderedDict([('X', array([[ -6,   5],
#        [-10,   3],
#        [  4,  -2]]))])
# array[3, 2] i64 n=6 x∈[-10, 5] μ=-1.000 σ=5.538 [[-6, 5], [-10, 3], [4, -2]]
# OrderedDict([('X', array([[-9, -2],
#        [ 6, -8],
#        [-5, -6]]))])
# array[3, 2] i64 n=6 x∈[-9, 6] μ=-4.000 σ=5.000 [[-9, -2], [6, -8], [-5, -6]]
# OrderedDict([('X', array([[-8, -5],
#        [ 2,  4],
#        [-2, -7],
#        [ 3, -6],
#        [-9,  0],
#        [-2, -8],
#        [-2, -8],
#        [-9,  1],
#        [-1, -2]]))])
# array[9, 2] i64 n=18 x∈[-9, 4] μ=-3.278 σ=4.201
# OrderedDict([('X', array([[ 2, -1],
#        [-7, -5],
#        [-4, -6],
#        [ 0,  2],
#        [ 8, -1],
#        [-1,  0]]))])
# array[6, 2] i64 n=12 x∈[-7, 8] μ=-1.083 σ=3.947
# OrderedDict([('X', array([[  4,  -6],
#        [ -7,   9],
#        [ -7,   7],
#        [ -7,   6],
#        [  1,   6],
#        [ -1, -10],
#        [  7,   7],
#        [  3,   4],
#        [  1,  -7]]))])
# array[9, 2] i64 n=18 x∈[-10, 9] μ=0.556 σ=6.103
# OrderedDict([('X', array([[ -8,   6],
#        [  1,   4],
#        [  5,  -6],
#        [  9,  -5],
#        [  8,  -6],
#        [ -8, -10],
#        [ -5,   4]]))])
# array[7, 2] i64 n=14 x∈[-10, 9] μ=-0.786 σ=6.438
# OrderedDict([('X', array([[-5,  5],
#        [-9, -3],
#        [ 0,  2],
#        [ 6, -3],
#        [ 7,  7]]))])
# array[5, 2] i64 n=10 x∈[-9, 7] μ=0.700 σ=5.311 [[-5, 5], [-9, -3], [0, 2], [6, -3], [7, 7]]
# OrderedDict([('X', array([[ -2,   6],
#        [  1,   3],
#        [  4,   5],
#        [  9, -10],
#        [ -1,  -3],
#        [  7, -10],
#        [ -9, -10]]))])
# array[7, 2] i64 n=14 x∈[-10, 9] μ=-0.714 σ=6.573
# OrderedDict([('X', array([[ 7,  9],
#        [ 4, -4],
#        [ 0,  9],
#        [ 5, -7],
#        [-5, -8],
#        [-2, -1],
#        [ 3,  0],
#        [ 7,  1],
#        [ 1,  2]]))])
# array[9, 2] i64 n=18 x∈[-8, 9] μ=1.167 σ=5.003
# OrderedDict([('X', array([[  2,   4],
#        [  0,  -1],
#        [ -8,   3],
#        [  5,  -1],
#        [ -1,   1],
#        [ -2, -10],
#        [ -6,   9],
#        [ -3,   0],
#        [  1, -10]]))])
# array[9, 2] i64 n=18 x∈[-10, 9] μ=-0.944 σ=4.927
# OrderedDict([('X', array([[  7,  -1],
#        [ -3,   7],
#        [-10,  -3],
#        [ -5,  -6],
#        [  4,   4]]))])
# array[5, 2] i64 n=10 x∈[-10, 7] μ=-0.600 σ=5.535 [[7, -1], [-3, 7], [-10, -3], [-5, -6], [4, 4]]
# OrderedDict([('X', array([[  8,   2],
#        [  0, -10],
#        [ -4,   4],
#        [-10,   1],
#        [ -4,   4],
#        [  8, -10]]))])
# array[6, 2] i64 n=12 x∈[-10, 8] μ=-0.917 σ=6.370
# OrderedDict([('X', array([[-8, -3],
#        [ 5, -9],
#        [-5,  1],
#        [-6, -9],
#        [ 5, -6],
#        [ 4,  1],
#        [-7,  4]]))])
# array[7, 2] i64 n=14 x∈[-9, 5] μ=-2.357 σ=5.259
# OrderedDict([('X', array([[-7,  2],
#        [ 8, -9],
#        [ 3, -7],
#        [ 5,  9]]))])
# array[4, 2] i64 n=8 x∈[-9, 9] μ=0.500 σ=6.708 [[-7, 2], [8, -9], [3, -7], [5, 9]]
# OrderedDict([('X', array([[-2, -2],
#        [ 4, -1],
#        [-1, -3],
#        [ 5,  6],
#        [-6, -7],
#        [ 7,  8],
#        [-7, -4],
#        [-1,  7]]))])
# array[8, 2] i64 n=16 x∈[-7, 8] μ=0.188 σ=5.052
# OrderedDict([('X', array([[-9, -6],
#        [ 1, -3]]))])
# array[2, 2] i64 n=4 x∈[-9, 1] μ=-4.250 σ=3.700 [[-9, -6], [1, -3]]
# OrderedDict([('X', array([[-8, -9],
#        [ 9, -3],
#        [ 1, -7],
#        [-6,  2],
#        [ 4,  5],
#        [-1,  5],
#        [ 1,  6]]))])
# array[7, 2] i64 n=14 x∈[-9, 9] μ=-0.071 σ=5.535
# OrderedDict([('X', array([[ 9, -5],
#        [ 7, -3]]))])
# array[2, 2] i64 n=4 x∈[-5, 9] μ=2.000 σ=6.083 [[9, -5], [7, -3]]
# OrderedDict([('X', array([[ -2, -10],
#        [  0,  -8],
#        [  9,  -7],
#        [  7,  -5],
#        [ -8,   0],
#        [  4,  -6]]))])
# array[6, 2] i64 n=12 x∈[-10, 9] μ=-2.167 σ=5.998
# OrderedDict([('X', array([[-8, -9],
#        [-9, -8]]))])
# array[2, 2] i64 n=4 x∈[-9, -8] μ=-8.500 σ=0.500 [[-8, -9], [-9, -8]]
# OrderedDict([('X', array([[ 2, -9],
#        [-3, -9]]))])
# array[2, 2] i64 n=4 x∈[-9, 2] μ=-4.750 σ=4.603 [[2, -9], [-3, -9]]
# OrderedDict([('X', array([[-9, -1],
#        [-9,  0],
#        [ 7,  4],
#        [-2,  8],
#        [-2, -8],
#        [-2,  3]]))])
# array[6, 2] i64 n=12 x∈[-9, 8] μ=-0.917 σ=5.530
# OrderedDict([('X', array([[ -6,  -9],
#        [ -5,   4],
#        [ -1,  -4],
#        [ -6, -10],
#        [  2,   7],
#        [  2,   7]]))])
# array[6, 2] i64 n=12 x∈[-10, 7] μ=-1.583 σ=5.678
# OrderedDict([('X', array([[-3,  6],
#        [ 4,  6],
#        [ 2,  8],
#        [-6,  1]]))])
# array[4, 2] i64 n=8 x∈[-6, 8] μ=2.250 σ=4.493 [[-3, 6], [4, 6], [2, 8], [-6, 1]]
# OrderedDict([('X', array([[ 5,  6],
#        [-3, -3],
#        [-2, -9],
#        [ 4,  7],
#        [-8,  6],
#        [-7, -7],
#        [ 3, -2]]))])
# array[7, 2] i64 n=14 x∈[-9, 7] μ=-0.714 σ=5.560
# OrderedDict([('X', array([[  8,  -4],
#        [  1,   4],
#        [ -6,   4],
#        [ -3,  -1],
#        [  5,  -3],
#        [-10,   1],
#        [ -6,  -8],
#        [-10,  -7]]))])
# array[8, 2] i64 n=16 x∈[-10, 8] μ=-2.188 σ=5.399
# OrderedDict([('X', array([[  8,   6],
#        [  3,   8],
#        [  2,   1],
#        [ -5,  -7],
#        [  8,   5],
#        [  2,  -7],
#        [  6, -10],
#        [  7,   9]]))])
# array[8, 2] i64 n=16 x∈[-10, 9] μ=2.250 σ=6.016
# OrderedDict([('X', array([[-1, -6],
#        [-7, -5]]))])
# array[2, 2] i64 n=4 x∈[-7, -1] μ=-4.750 σ=2.278 [[-1, -6], [-7, -5]]
# OrderedDict([('X', array([[-7,  1],
#        [-1, -4],
#        [-8,  3],
#        [-1,  5],
#        [ 5, -1],
#        [ 2, -5],
#        [ 1, -2],
#        [ 2, -7],
#        [ 0,  9]]))])
# array[9, 2] i64 n=18 x∈[-8, 9] μ=-0.444 σ=4.450
# OrderedDict([('X', array([[ 7, -6],
#        [-8, -6],
#        [ 6,  8]]))])
# array[3, 2] i64 n=6 x∈[-8, 8] μ=0.167 σ=6.890 [[7, -6], [-8, -6], [6, 8]]
# OrderedDict([('X', array([[ -9, -10],
#        [ -1,  -6],
#        [ -9,   5],
#        [ -9,  -1],
#        [ -9,   5],
#        [  5,   8],
#        [ -4,   1]]))])
# array[7, 2] i64 n=14 x∈[-10, 8] μ=-2.429 σ=6.184
# OrderedDict([('X', array([[ -1,   9],
#        [ -5,   1],
#        [ -9,  -4],
#        [  5,  -8],
#        [  2,  -8],
#        [  7,   0],
#        [ -3,  -5],
#        [-10, -10],
#        [ -3,  -6]]))])
# array[9, 2] i64 n=18 x∈[-10, 9] μ=-2.667 σ=5.588
# OrderedDict([('X', array([[ 7, -5],
#        [ 8,  1],
#        [ 0, -9],
#        [ 4,  1],
#        [ 1, -2]]))])
# array[5, 2] i64 n=10 x∈[-9, 8] μ=0.600 σ=4.883 [[7, -5], [8, 1], [0, -9], [4, 1], [1, -2]]
# OrderedDict([('X', array([[ 4, -5],
#        [ 4, -8],
#        [ 3,  9],
#        [ 3, -7],
#        [ 1,  6]]))])
# array[5, 2] i64 n=10 x∈[-8, 9] μ=1.000 σ=5.441 [[4, -5], [4, -8], [3, 9], [3, -7], [1, 6]]
# OrderedDict([('X', array([[ 8,  3],
#        [ 9,  6],
#        [-3,  3],
#        [-5,  5],
#        [ 8,  3],
#        [ 8, -8],
#        [-1,  8]]))])
# array[7, 2] i64 n=14 x∈[-8, 9] μ=3.143 σ=5.249
# OrderedDict([('X', array([[-2,  5],
#        [ 6,  5],
#        [ 1, -8],
#        [ 0,  3],
#        [ 7, -6],
#        [ 5,  9]]))])
# array[6, 2] i64 n=12 x∈[-8, 9] μ=2.083 σ=5.024
# OrderedDict([('X', array([[  7,   6],
#        [  1,  -5],
#        [ -3,   8],
#        [ -1, -10],
#        [  2,   6],
#        [ -8,  -3],
#        [  3,  -8]]))])
# array[7, 2] i64 n=14 x∈[-10, 8] μ=-0.357 σ=5.789
# OrderedDict([('X', array([[ 6, -1],
#        [ 0, -2],
#        [-2, -6],
#        [ 6, -2],
#        [ 6,  8],
#        [-4, -2]]))])
# array[6, 2] i64 n=12 x∈[-6, 8] μ=0.583 σ=4.443
# OrderedDict([('X', array([[  8,   4],
#        [ -3,   9],
#        [  6, -10]]))])
# array[3, 2] i64 n=6 x∈[-10, 9] μ=2.333 σ=6.749 [[8, 4], [-3, 9], [6, -10]]
# OrderedDict([('X', array([[ 9, -5],
#        [-9, -5],
#        [-8,  5],
#        [-3, -9],
#        [ 6, -2]]))])
# array[5, 2] i64 n=10 x∈[-9, 9] μ=-2.100 σ=6.220 [[9, -5], [-9, -5], [-8, 5], [-3, -9], [6, -2]]
# OrderedDict([('X', array([[  4,  -2],
#        [ -3,   0],
#        [  5,  -7],
#        [-10,  -4],
#        [ -9,  -6]]))])
# array[5, 2] i64 n=10 x∈[-10, 5] μ=-3.200 σ=4.833 [[4, -2], [-3, 0], [5, -7], [-10, -4], [-9, -6]]
# OrderedDict([('X', array([[ 6,  2],
#        [ 7, -6],
#        [-8,  0],
#        [ 2, -7],
#        [ 3,  0],
#        [-1,  8],
#        [ 7, -5],
#        [ 4, -1]]))])
# array[8, 2] i64 n=16 x∈[-8, 8] μ=0.688 σ=4.996
# OrderedDict([('X', array([[-9,  0],
#        [-7,  8],
#        [ 6, -8],
#        [ 7, -3],
#        [ 8, -6],
#        [-4, -3]]))])
# array[6, 2] i64 n=12 x∈[-9, 8] μ=-0.917 σ=6.238
# OrderedDict([('X', array([[  2,   6],
#        [  6,   6],
#        [-10,  -3],
#        [  8,  -5],
#        [ -8,  -6],
#        [  2,   4],
#        [  3,   5],
#        [  7,   0],
#        [ -8,  -1]]))])
# array[9, 2] i64 n=18 x∈[-10, 8] μ=0.444 σ=5.649
# OrderedDict([('X', array([[ 2,  8],
#        [-5,  5],
#        [-9, -3],
#        [ 6, -9],
#        [-1,  5],
#        [-5, -9],
#        [-9,  2],
#        [ 4, -9],
#        [-4, -8]]))])
# array[9, 2] i64 n=18 x∈[-9, 8] μ=-2.167 σ=5.937
# OrderedDict([('X', array([[ 3, -9],
#        [ 7, -9],
#        [ 0, -2],
#        [ 1,  6],
#        [ 4,  6]]))])
# array[5, 2] i64 n=10 x∈[-9, 7] μ=0.700 σ=5.551 [[3, -9], [7, -9], [0, -2], [1, 6], [4, 6]]
# OrderedDict([('X', array([[-2,  9],
#        [ 8,  8],
#        [ 1, -6],
#        [-1,  6],
#        [-6,  5]]))])
# array[5, 2] i64 n=10 x∈[-6, 9] μ=2.200 σ=5.474 [[-2, 9], [8, 8], [1, -6], [-1, 6], [-6, 5]]
# OrderedDict([('X', array([[ 0, -8],
#        [ 2,  6],
#        [-1,  1],
#        [ 4, -1],
#        [ 3,  2]]))])
# array[5, 2] i64 n=10 x∈[-8, 6] μ=0.800 σ=3.600 [[0, -8], [2, 6], [-1, 1], [4, -1], [3, 2]]
# OrderedDict([('X', array([[-10,  -4],
#        [  9,   1],
#        [  5,   5],
#        [  0,  -7],
#        [  2,  -4],
#        [ -7,   4],
#        [  8,  -2],
#        [  0,  -3]]))])
# array[8, 2] i64 n=16 x∈[-10, 9] μ=-0.188 σ=5.353
# OrderedDict([('X', array([[ 6,  5],
#        [ 0,  2],
#        [ 7,  0],
#        [ 1, -5],
#        [-2,  5]]))])
# array[5, 2] i64 n=10 x∈[-5, 7] μ=1.900 σ=3.646 [[6, 5], [0, 2], [7, 0], [1, -5], [-2, 5]]
# OrderedDict([('X', array([[-7,  1],
#        [ 8, -9],
#        [ 6,  0]]))])
# array[3, 2] i64 n=6 x∈[-9, 8] μ=-0.167 σ=6.203 [[-7, 1], [8, -9], [6, 0]]
# OrderedDict([('X', array([[-1,  0],
#        [-1, -3],
#        [-9, -3],
#        [ 5, -6],
#        [-8,  1],
#        [ 2,  2]]))])
# array[6, 2] i64 n=12 x∈[-9, 5] μ=-1.750 σ=4.065
# OrderedDict([('X', array([[ -2,  -2],
#        [ -6, -10],
#        [  6,  -9],
#        [  2,  -2]]))])
# array[4, 2] i64 n=8 x∈[-10, 6] μ=-2.875 σ=5.036 [[-2, -2], [-6, -10], [6, -9], [2, -2]]
# OrderedDict([('X', array([[ 9,  4],
#        [ 7,  9],
#        [ 2, -3],
#        [-2,  5],
#        [ 8,  5],
#        [-4,  3],
#        [ 3, -7],
#        [ 4, -8]]))])
# array[8, 2] i64 n=16 x∈[-8, 9] μ=2.188 σ=5.270
# OrderedDict([('X', array([[ 8,  4],
#        [-7,  1],
#        [-5,  8],
#        [-7,  4]]))])
# array[4, 2] i64 n=8 x∈[-7, 8] μ=0.750 σ=5.911 [[8, 4], [-7, 1], [-5, 8], [-7, 4]]
# OrderedDict([('X', array([[ -9,  -3],
#        [  4,  -4],
#        [ -5, -10],
#        [  4,  -4],
#        [  6,  -9],
#        [ -2,  -2],
#        [  2,  -5],
#        [ -5,   9]]))])
# array[8, 2] i64 n=16 x∈[-10, 9] μ=-2.062 σ=5.425
# OrderedDict([('X', array([[  3,  -6],
#        [-10,   7],
#        [  5,  -2],
#        [  8,  -6],
#        [ -9,   4],
#        [ -4,  -7]]))])
# array[6, 2] i64 n=12 x∈[-10, 8] μ=-1.417 σ=6.198
# OrderedDict([('X', array([[-1,  6],
#        [-9, -5],
#        [-6, -2]]))])
# array[3, 2] i64 n=6 x∈[-9, 6] μ=-2.833 σ=4.740 [[-1, 6], [-9, -5], [-6, -2]]
# OrderedDict([('X', array([[ 9,  1],
#        [ 8,  9],
#        [-8,  4],
#        [-9, -9]]))])
# array[4, 2] i64 n=8 x∈[-9, 9] μ=0.625 σ=7.631 [[9, 1], [8, 9], [-8, 4], [-9, -9]]
# OrderedDict([('X', array([[ -7,  -9],
#        [ -7, -10]]))])
# array[2, 2] i64 n=4 x∈[-10, -7] μ=-8.250 σ=1.299 [[-7, -9], [-7, -10]]
# OrderedDict([('X', array([[  6,   2],
#        [ -7,  -4],
#        [  6,  -2],
#        [ -7,   8],
#        [-10,  -1]]))])
# array[5, 2] i64 n=10 x∈[-10, 8] μ=-0.900 σ=5.924 [[6, 2], [-7, -4], [6, -2], [-7, 8], [-10, -1]]
# OrderedDict([('X', array([[ 7, -8],
#        [ 9,  4],
#        [ 4, -7]]))])
# array[3, 2] i64 n=6 x∈[-8, 9] μ=1.500 σ=6.602 [[7, -8], [9, 4], [4, -7]]
# OrderedDict([('X', array([[  4,   9],
#        [  4, -10],
#        [  3,  -6],
#        [  0,   5],
#        [ -9,  -3],
#        [  0,   7]]))])
# array[6, 2] i64 n=12 x∈[-10, 9] μ=0.333 σ=5.921
# OrderedDict([('X', array([[ -7,   4],
#        [-10,  -8],
#        [  3,  -5],
#        [  7, -10],
#        [ -5,  -5],
#        [  5,  -6],
#        [  6,  -1]]))])
# array[7, 2] i64 n=14 x∈[-10, 7] μ=-2.286 σ=5.897
# OrderedDict([('X', array([[  8,  -7],
#        [ -9,  -2],
#        [ -1,   0],
#        [  3,  -4],
#        [  4,   8],
#        [  4,  -3],
#        [  0,  -2],
#        [  4, -10]]))])
# array[8, 2] i64 n=16 x∈[-10, 8] μ=-0.438 σ=5.279
# OrderedDict([('X', array([[ 1,  8],
#        [-2, -4]]))])
# array[2, 2] i64 n=4 x∈[-4, 8] μ=0.750 σ=4.548 [[1, 8], [-2, -4]]
# OrderedDict([('X', array([[ 3, -3],
#        [ 7,  8],
#        [ 5, -9],
#        [-3, -5]]))])
# array[4, 2] i64 n=8 x∈[-9, 8] μ=0.375 σ=5.808 [[3, -3], [7, 8], [5, -9], [-3, -5]]
# OrderedDict([('X', array([[ 0, -9],
#        [ 6, -2],
#        [-9,  4],
#        [ 5, -7],
#        [-3, -2],
#        [-6,  5],
#        [ 2, -4],
#        [ 9,  6],
#        [-8, -6]]))])
# array[9, 2] i64 n=18 x∈[-9, 9] μ=-1.056 σ=5.691
# OrderedDict([('X', array([[ -8,  -5],
#        [ -8, -10]]))])
# array[2, 2] i64 n=4 x∈[-10, -5] μ=-7.750 σ=1.785 [[-8, -5], [-8, -10]]
# OrderedDict([('X', array([[-10,  -6],
#        [ -5,  -8],
#        [  4,  -6],
#        [  3,   7],
#        [  5,  -5]]))])
# array[5, 2] i64 n=10 x∈[-10, 7] μ=-2.100 σ=5.839 [[-10, -6], [-5, -8], [4, -6], [3, 7], [5, -5]]
# OrderedDict([('X', array([[ 8,  0],
#        [-9, -1],
#        [ 0,  9],
#        [ 5,  8],
#        [ 0,  3],
#        [-9, -6]]))])
# array[6, 2] i64 n=12 x∈[-9, 9] μ=0.667 σ=6.032

# %% [markdown]
# # Task 1. Vector lenghts
#
# - Write a function that calculates vector lengths, answer should return array of shape $2$
# - Apply this function to all the inputs

# %%
def get_lengths(X):
    res = np.sqrt((X**2).sum(axis=0))
    return res

# %%
answers['lengths'] = [
    get_lengths(**inp) for inp in inputs
]
answers['lengths']
# Out:
# [array([3.16227766, 4.47213595]),
#  array([17.43559577, 14.56021978]),
#  array([9.11043358, 5.83095189]),
#  array([10.77032961,  2.23606798]),
#  array([17.88854382, 17.63519209]),
#  array([15.68438714, 17.69180601]),
#  array([16.85229955, 21.49418526]),
#  array([16.37070554, 18.38477631]),
#  array([18.43908891, 18.62793601]),
#  array([9.89949494, 7.34846923]),
#  array([15.49193338, 13.49073756]),
#  array([13.60147051, 17.1464282 ]),
#  array([13.67479433, 11.48912529]),
#  array([13.96424004, 12.16552506]),
#  array([13.67479433, 14.45683229]),
#  array([19.97498436, 11.26942767]),
#  array([12.40967365, 17.34935157]),
#  array([16.85229955, 15.96871942]),
#  array([11.13552873, 18.41195264]),
#  array([6.40312424, 7.28010989]),
#  array([ 6.70820393, 10.34408043]),
#  array([11.66190379, 10.34408043]),
#  array([9.21954446, 8.        ]),
#  array([16.03121954, 15.06651917]),
#  array([15.26433752, 15.29705854]),
#  array([ 9.2736185 , 10.48808848]),
#  array([15.71623365, 14.        ]),
#  array([8.60232527, 8.83176087]),
#  array([16.30950643, 17.74823935]),
#  array([ 7.21110255, 13.45362405]),
#  array([12.32882801,  6.164414  ]),
#  array([11.91637529, 10.19803903]),
#  array([15.87450787, 16.09347694]),
#  array([11.5758369 ,  8.18535277]),
#  array([14.96662955, 21.26029163]),
#  array([18.       , 16.2788206]),
#  array([13.82027496,  9.79795897]),
#  array([15.26433752, 19.46792233]),
#  array([13.34166406, 17.23368794]),
#  array([12.        , 17.57839583]),
#  array([14.10673598, 10.53565375]),
#  array([16.1245155 , 15.39480432]),
#  array([15.49193338, 15.        ]),
#  array([12.12435565, 14.6628783 ]),
#  array([13.45362405, 15.09966887]),
#  array([9.05538514, 6.70820393]),
#  array([14.14213562, 15.13274595]),
#  array([11.40175425,  5.83095189]),
#  array([14.62873884, 16.55294536]),
#  array([12.04159458, 12.04159458]),
#  array([ 3.60555128, 12.72792206]),
#  array([14.93318452, 12.40967365]),
#  array([10.29563014, 17.63519209]),
#  array([ 8.06225775, 11.70469991]),
#  array([13.26649916, 16.24807681]),
#  array([19.26136028, 13.11487705]),
#  array([15.96871942, 20.1246118 ]),
#  array([7.07106781, 7.81024968]),
#  array([12.20655562, 14.52583905]),
#  array([12.20655562, 11.66190379]),
#  array([19.13112647, 15.87450787]),
#  array([17.40689519, 19.67231557]),
#  array([11.40175425, 10.58300524]),
#  array([ 7.14142843, 15.96871942]),
#  array([17.54992877, 14.69693846]),
#  array([10.72380529, 15.49193338]),
#  array([11.70469991, 18.27566688]),
#  array([11.3137085 , 10.63014581]),
#  array([10.44030651, 14.03566885]),
#  array([16.46207763, 12.64911064]),
#  array([15.19868415, 10.24695077]),
#  array([15.09966887, 13.37908816]),
#  array([17.17556404, 13.49073756]),
#  array([19.84943324, 13.56465997]),
#  array([16.88194302, 20.83266666]),
#  array([ 8.66025404, 15.42724862]),
#  array([10.29563014, 15.55634919]),
#  array([ 5.47722558, 10.29563014]),
#  array([17.97220076, 11.66190379]),
#  array([9.48683298, 8.88819442]),
#  array([12.20655562,  9.05538514]),
#  array([13.26649916,  7.68114575]),
#  array([ 8.94427191, 13.74772708]),
#  array([15.58845727, 16.673332  ]),
#  array([13.67479433,  9.8488578 ]),
#  array([14.38749457, 18.22086716]),
#  array([17.17556404, 13.78404875]),
#  array([10.86278049,  8.06225775]),
#  array([17.02938637, 13.37908816]),
#  array([ 9.89949494, 13.45362405]),
#  array([16.43167673,  9.43398113]),
#  array([12.08304597, 11.35781669]),
#  array([11.04536102, 17.32050808]),
#  array([17.11724277, 16.34013464]),
#  array([14.24780685, 15.68438714]),
#  array([2.23606798, 8.94427191]),
#  array([ 9.59166305, 13.37908816]),
#  array([18.33030278, 16.34013464]),
#  array([11.3137085 , 11.18033989]),
#  array([13.22875656, 14.49137675]),
#  array([15.84297952, 13.82027496])]

# %% [markdown]
# # Task 2. Vector directions
#
# - Write a function that calculates vector directions. Result should be of the same shape as the original array X
# - Use $10^{-8}$ addition in division to avoid division by zero
# - Apply this function to all arrays in the inputs

# %%
def get_directions(X):
    res = None
    lenght = np.sqrt((X**2).sum(axis=0))
    res = X / lenght
    return res

# %%
answers['directions'] = [
    get_directions(**inp) for inp in inputs
]
answers['directions']
# Out:
# [array([[0.31622777, 0.4472136 ],
#         [0.9486833 , 0.89442719]]),
#  array([[ 0.22941573,  0.        ],
#         [-0.1720618 , -0.27472113],
#         [ 0.45883147,  0.        ],
#         [ 0.        , -0.48076197],
#         [-0.1720618 , -0.54944226],
#         [-0.5161854 ,  0.06868028],
#         [-0.28676967, -0.61812254],
#         [-0.57353933,  0.06868028]]),
#  array([[-0.76834982,  0.51449576],
#         [ 0.5488213 ,  0.68599434],
#         [-0.32929278,  0.51449576]]),
#  array([[-0.37139068, -0.89442719],
#         [-0.92847669,  0.4472136 ]]),
#  array([[-0.4472136 , -0.56704798],
#         [-0.3354102 , -0.0567048 ],
#         [-0.2236068 , -0.1134096 ],
#         [-0.2236068 , -0.1134096 ],
#         [-0.1677051 ,  0.0567048 ],
#         [-0.50311529, -0.56704798],
#         [ 0.2795085 , -0.34022879],
#         [-0.4472136 ,  0.0567048 ],
#         [-0.1677051 , -0.45363838]]),
#  array([[ 0.        , -0.22609337],
#         [-0.63757671, -0.56523342],
#         [ 0.57381904,  0.11304668],
#         [-0.12751534, -0.45218674],
#         [-0.25503069, -0.28261671],
#         [-0.19127301, -0.11304668],
#         [-0.38254603, -0.56523342]]),
#  array([[ 0.53405175, -0.09304842],
#         [-0.59339083, -0.13957263],
#         [-0.23735633,  0.32566947],
#         [-0.17801725, -0.46524211],
#         [ 0.        ,  0.32566947],
#         [-0.05933908, -0.37219368],
#         [-0.23735633,  0.23262105],
#         [ 0.29669541,  0.41871789],
#         [ 0.3560345 , -0.41871789]]),
#  array([[-0.48867778, -0.54392829],
#         [ 0.5497625 , -0.54392829],
#         [-0.48867778,  0.38074981],
#         [-0.06108472, -0.43514263],
#         [-0.18325417,  0.16317849],
#         [ 0.42759306,  0.21757132]]),
#  array([[ 0.48809353,  0.26841406],
#         [ 0.10846523,  0.37577969],
#         [-0.05423261,  0.4294625 ],
#         [ 0.32539569,  0.4294625 ],
#         [-0.32539569, -0.10736563],
#         [ 0.05423261, -0.53682813],
#         [-0.54232614,  0.21473125],
#         [-0.48809353,  0.26841406]]),
#  array([[ 0.70710678,  0.27216553],
#         [ 0.        , -0.95257934],
#         [-0.70710678, -0.13608276]]),
#  array([[ 0.32274861,  0.14824986],
#         [ 0.51639778,  0.44474959],
#         [-0.45184806,  0.07412493],
#         [-0.12909944,  0.59299945],
#         [ 0.06454972, -0.14824986],
#         [-0.25819889,  0.22237479],
#         [ 0.5809475 ,  0.59299945]]),
#  array([[-0.22056439,  0.29160592],
#         [ 0.14704292, -0.58321184],
#         [ 0.66169316,  0.34992711],
#         [-0.29408585,  0.11664237],
#         [-0.51465024, -0.40824829],
#         [-0.36760731,  0.46656947],
#         [ 0.07352146, -0.23328474]]),
#  array([[ 0.5118907 ,  0.34815531],
#         [-0.14625448,  0.52223297],
#         [ 0.21938173,  0.34815531],
#         [-0.73127242, -0.69631062],
#         [ 0.36563621,  0.        ]]),
#  array([[-0.42966892, -0.16439899],
#         [-0.50128041,  0.49319696],
#         [-0.14322297, -0.82199494],
#         [ 0.64450339,  0.16439899],
#         [ 0.35805744,  0.16439899]]),
#  array([[-0.36563621,  0.41502868],
#         [-0.43876345, -0.41502868],
#         [-0.36563621, -0.55337157],
#         [-0.43876345, -0.41502868],
#         [-0.07312724, -0.06917145],
#         [ 0.58501794,  0.41502868]]),
#  array([[-0.45056356, -0.44367825],
#         [-0.45056356,  0.1774713 ],
#         [ 0.        ,  0.        ],
#         [ 0.25031309,  0.        ],
#         [ 0.40050094,  0.3549426 ],
#         [ 0.25031309,  0.        ],
#         [ 0.25031309, -0.26620695],
#         [-0.35043832, -0.26620695],
#         [-0.35043832, -0.70988521]]),
#  array([[ 0.0805823 ,  0.34583425],
#         [ 0.16116459,  0.51875138],
#         [-0.56407607, -0.05763904],
#         [-0.64465837, -0.11527808],
#         [ 0.16116459,  0.40347329],
#         [ 0.32232919, -0.40347329],
#         [ 0.32232919, -0.51875138]]),
#  array([[-0.11867817, -0.50097943],
#         [ 0.47471266, -0.18786729],
#         [-0.3560345 , -0.438357  ],
#         [-0.29669541, -0.56360186],
#         [ 0.53405175,  0.        ],
#         [-0.41537358,  0.25048972],
#         [-0.29669541,  0.37573457]]),
#  array([[ 0.53881591, -0.32587527],
#         [ 0.08980265,  0.38018781],
#         [ 0.26940795,  0.        ],
#         [-0.1796053 , -0.4888129 ],
#         [ 0.08980265, -0.43450036],
#         [-0.71842121, -0.54312545],
#         [-0.26940795, -0.16293763]]),
#  array([[-0.78086881,  0.27472113],
#         [ 0.62469505, -0.96152395]]),
#  array([[-0.89442719,  0.87006284],
#         [ 0.        , -0.09667365],
#         [-0.4472136 , -0.48336824]]),
#  array([[ 0.08574929,  0.09667365],
#         [-0.60024505,  0.48336824],
#         [-0.60024505, -0.58004189],
#         [-0.51449576, -0.29002095],
#         [-0.08574929,  0.58004189]]),
#  array([[-0.21693046, -1.        ],
#         [ 0.97618706,  0.        ]]),
#  array([[-0.62378286,  0.39823399],
#         [ 0.        ,  0.46460632],
#         [ 0.37426972, -0.26548932],
#         [ 0.37426972,  0.59735098],
#         [-0.12475657,  0.39823399],
#         [ 0.56140458, -0.19911699]]),
#  array([[ 0.19653653,  0.32686023],
#         [ 0.45858525, -0.26148818],
#         [-0.06551218, -0.26148818],
#         [-0.65512178,  0.52297636],
#         [ 0.32756089,  0.52297636],
#         [-0.45858525,  0.45760432]]),
#  array([[-0.10783277, -0.66742381],
#         [-0.21566555, -0.47673129],
#         [-0.97049496,  0.57207755]]),
#  array([[-0.57265629,  0.28571429],
#         [-0.38177086, -0.71428571],
#         [-0.44539933,  0.28571429],
#         [ 0.57265629,  0.57142857]]),
#  array([[ 0.11624764,  0.67936622],
#         [ 0.69748583, -0.1132277 ],
#         [ 0.69748583,  0.45291081],
#         [ 0.11624764,  0.56613852]]),
#  array([[ 0.42919754,  0.50709255],
#         [-0.24525574, -0.45074894],
#         [ 0.42919754, -0.05634362],
#         [-0.24525574,  0.3380617 ],
#         [ 0.1839418 , -0.45074894],
#         [ 0.06131393,  0.11268723],
#         [-0.55182541, -0.45074894],
#         [-0.3678836 ,  0.        ],
#         [-0.1839418 ,  0.05634362]]),
#  array([[-0.5547002 ,  0.66896473],
#         [-0.83205029, -0.74329415]]),
#  array([[-0.48666426,  0.81110711],
#         [-0.81110711,  0.48666426],
#         [ 0.32444284, -0.32444284]]),
#  array([[-0.75526322, -0.19611614],
#         [ 0.50350881, -0.78446454],
#         [-0.41959068, -0.58834841]]),
#  array([[-0.50395263, -0.31068488],
#         [ 0.12598816,  0.24854791],
#         [-0.12598816, -0.43495884],
#         [ 0.18898224, -0.37282186],
#         [-0.56694671,  0.        ],
#         [-0.12598816, -0.49709581],
#         [-0.12598816, -0.49709581],
#         [-0.56694671,  0.06213698],
#         [-0.06299408, -0.12427395]]),
#  array([[ 0.17277369, -0.12216944],
#         [-0.6047079 , -0.61084722],
#         [-0.34554737, -0.73301667],
#         [ 0.        ,  0.24433889],
#         [ 0.69109474, -0.12216944],
#         [-0.08638684,  0.        ]]),
#  array([[ 0.26726124, -0.28221626],
#         [-0.46770717,  0.42332439],
#         [-0.46770717,  0.3292523 ],
#         [-0.46770717,  0.28221626],
#         [ 0.06681531,  0.28221626],
#         [-0.06681531, -0.47036043],
#         [ 0.46770717,  0.3292523 ],
#         [ 0.20044593,  0.18814417],
#         [ 0.06681531, -0.3292523 ]]),
#  array([[-0.44444444,  0.36857707],
#         [ 0.05555556,  0.24571805],
#         [ 0.27777778, -0.36857707],
#         [ 0.5       , -0.30714756],
#         [ 0.44444444, -0.36857707],
#         [-0.44444444, -0.61429512],
#         [-0.27777778,  0.24571805]]),
#  array([[-0.3617873 ,  0.51031036],
#         [-0.65121714, -0.30618622],
#         [ 0.        ,  0.20412415],
#         [ 0.43414476, -0.30618622],
#         [ 0.50650222,  0.71443451]]),
#  array([[-0.13102436,  0.3081993 ],
#         [ 0.06551218,  0.15409965],
#         [ 0.26204871,  0.25683275],
#         [ 0.5896096 , -0.5136655 ],
#         [-0.06551218, -0.15409965],
#         [ 0.45858525, -0.5136655 ],
#         [-0.5896096 , -0.5136655 ]]),
#  array([[ 0.52467218,  0.52223297],
#         [ 0.29981268, -0.23210354],
#         [ 0.        ,  0.52223297],
#         [ 0.37476584, -0.4061812 ],
#         [-0.37476584, -0.46420708],
#         [-0.14990634, -0.05802589],
#         [ 0.22485951,  0.        ],
#         [ 0.52467218,  0.05802589],
#         [ 0.07495317,  0.11605177]]),
#  array([[ 0.16666667,  0.22755205],
#         [ 0.        , -0.05688801],
#         [-0.66666667,  0.17066404],
#         [ 0.41666667, -0.05688801],
#         [-0.08333333,  0.05688801],
#         [-0.16666667, -0.56888012],
#         [-0.5       ,  0.51199211],
#         [-0.25      ,  0.        ],
#         [ 0.08333333, -0.56888012]]),
#  array([[ 0.49621684, -0.0949158 ],
#         [-0.21266436,  0.6644106 ],
#         [-0.70888121, -0.2847474 ],
#         [-0.3544406 , -0.5694948 ],
#         [ 0.28355248,  0.3796632 ]]),
#  array([[ 0.49613894,  0.12991396],
#         [ 0.        , -0.6495698 ],
#         [-0.24806947,  0.25982792],
#         [-0.62017367,  0.06495698],
#         [-0.24806947,  0.25982792],
#         [ 0.49613894, -0.6495698 ]]),
#  array([[-0.51639778, -0.2       ],
#         [ 0.32274861, -0.6       ],
#         [-0.32274861,  0.06666667],
#         [-0.38729833, -0.6       ],
#         [ 0.32274861, -0.4       ],
#         [ 0.25819889,  0.06666667],
#         [-0.45184806,  0.26666667]]),
#  array([[-0.57735027,  0.13639887],
#         [ 0.65982888, -0.61379491],
#         [ 0.24743583, -0.47739604],
#         [ 0.41239305,  0.61379491]]),
#  array([[-0.14865883, -0.13245324],
#         [ 0.29731766, -0.06622662],
#         [-0.07432941, -0.19867985],
#         [ 0.37164707,  0.39735971],
#         [-0.44597649, -0.46358632],
#         [ 0.5203059 ,  0.52981294],
#         [-0.5203059 , -0.26490647],
#         [-0.07432941,  0.46358632]]),
#  array([[-0.99388373, -0.89442719],
#         [ 0.11043153, -0.4472136 ]]),
#  array([[-0.56568542, -0.59473674],
#         [ 0.6363961 , -0.19824558],
#         [ 0.07071068, -0.46257302],
#         [-0.42426407,  0.13216372],
#         [ 0.28284271,  0.3304093 ],
#         [-0.07071068,  0.3304093 ],
#         [ 0.07071068,  0.39649116]]),
#  array([[ 0.78935222, -0.85749293],
#         [ 0.61394061, -0.51449576]]),
#  array([[-0.13671719, -0.60412209],
#         [ 0.        , -0.48329767],
#         [ 0.61522733, -0.42288547],
#         [ 0.47851015, -0.30206105],
#         [-0.54686874,  0.        ],
#         [ 0.27343437, -0.36247326]]),
#  array([[-0.66436384, -0.74740932],
#         [-0.74740932, -0.66436384]]),
#  array([[ 0.5547002 , -0.70710678],
#         [-0.83205029, -0.70710678]]),
#  array([[-0.60268458, -0.0805823 ],
#         [-0.60268458,  0.        ],
#         [ 0.46875467,  0.32232919],
#         [-0.13392991,  0.64465837],
#         [-0.13392991, -0.64465837],
#         [-0.13392991,  0.24174689]]),
#  array([[-0.58277152, -0.51034318],
#         [-0.48564293,  0.22681919],
#         [-0.09712859, -0.22681919],
#         [-0.58277152, -0.56704798],
#         [ 0.19425717,  0.39693358],
#         [ 0.19425717,  0.39693358]]),
#  array([[-0.3721042 ,  0.51261459],
#         [ 0.49613894,  0.51261459],
#         [ 0.24806947,  0.68348613],
#         [-0.74420841,  0.08543577]]),
#  array([[ 0.37688918,  0.36927447],
#         [-0.22613351, -0.18463724],
#         [-0.15075567, -0.55391171],
#         [ 0.30151134,  0.43082022],
#         [-0.60302269,  0.36927447],
#         [-0.52764485, -0.43082022],
#         [ 0.22613351, -0.12309149]]),
#  array([[ 0.41533931, -0.30499714],
#         [ 0.05191741,  0.30499714],
#         [-0.31150448,  0.30499714],
#         [-0.15575224, -0.07624929],
#         [ 0.25958707, -0.22874786],
#         [-0.51917413,  0.07624929],
#         [-0.31150448, -0.60999428],
#         [-0.51917413, -0.533745  ]]),
#  array([[ 0.50097943,  0.2981424 ],
#         [ 0.18786729,  0.3975232 ],
#         [ 0.12524486,  0.0496904 ],
#         [-0.31311215, -0.3478328 ],
#         [ 0.50097943,  0.248452  ],
#         [ 0.12524486, -0.3478328 ],
#         [ 0.37573457, -0.49690399],
#         [ 0.438357  ,  0.4472136 ]]),
#  array([[-0.14142136, -0.76822128],
#         [-0.98994949, -0.6401844 ]]),
#  array([[-0.57346234,  0.06884284],
#         [-0.08192319, -0.27537136],
#         [-0.65538554,  0.20652852],
#         [-0.08192319,  0.3442142 ],
#         [ 0.40961596, -0.06884284],
#         [ 0.16384638, -0.3442142 ],
#         [ 0.08192319, -0.13768568],
#         [ 0.16384638, -0.48189987],
#         [ 0.        ,  0.61958555]]),
#  array([[ 0.57346234, -0.51449576],
#         [-0.65538554, -0.51449576],
#         [ 0.49153915,  0.68599434]]),
#  array([[-0.47043754, -0.62994079],
#         [-0.05227084, -0.37796447],
#         [-0.47043754,  0.31497039],
#         [-0.47043754, -0.06299408],
#         [-0.47043754,  0.31497039],
#         [ 0.26135419,  0.50395263],
#         [-0.20908335,  0.06299408]]),
#  array([[-0.0574485 ,  0.45749571],
#         [-0.28724249,  0.05083286],
#         [-0.51703649, -0.20333143],
#         [ 0.28724249, -0.40666285],
#         [ 0.114897  , -0.40666285],
#         [ 0.40213949,  0.        ],
#         [-0.1723455 , -0.25416428],
#         [-0.57448499, -0.50832857],
#         [-0.1723455 , -0.30499714]]),
#  array([[ 0.61394061, -0.47245559],
#         [ 0.70164642,  0.09449112],
#         [ 0.        , -0.85042006],
#         [ 0.35082321,  0.09449112],
#         [ 0.0877058 , -0.18898224]]),
#  array([[ 0.56011203, -0.31311215],
#         [ 0.56011203, -0.50097943],
#         [ 0.42008403,  0.56360186],
#         [ 0.42008403, -0.438357  ],
#         [ 0.14002801,  0.37573457]]),
#  array([[ 0.45584231,  0.20412415],
#         [ 0.51282259,  0.40824829],
#         [-0.17094086,  0.20412415],
#         [-0.28490144,  0.34020691],
#         [ 0.45584231,  0.20412415],
#         [ 0.45584231, -0.54433105],
#         [-0.05698029,  0.54433105]]),
#  array([[-0.18650096,  0.32274861],
#         [ 0.55950288,  0.32274861],
#         [ 0.09325048, -0.51639778],
#         [ 0.        ,  0.19364917],
#         [ 0.65275337, -0.38729833],
#         [ 0.4662524 ,  0.5809475 ]]),
#  array([[ 0.59805036,  0.32830539],
#         [ 0.08543577, -0.27358783],
#         [-0.2563073 ,  0.43774052],
#         [-0.08543577, -0.54717566],
#         [ 0.17087153,  0.32830539],
#         [-0.68348613, -0.1641527 ],
#         [ 0.2563073 , -0.43774052]]),
#  array([[ 0.53033009, -0.09407209],
#         [ 0.        , -0.18814417],
#         [-0.1767767 , -0.56443252],
#         [ 0.53033009, -0.18814417],
#         [ 0.53033009,  0.75257669],
#         [-0.35355339, -0.18814417]]),
#  array([[ 0.76626103,  0.2849882 ],
#         [-0.28734789,  0.64122345],
#         [ 0.57469577, -0.7124705 ]]),
#  array([[ 0.54671107, -0.39528471],
#         [-0.54671107, -0.39528471],
#         [-0.48596539,  0.39528471],
#         [-0.18223702, -0.71151247],
#         [ 0.36447404, -0.15811388]]),
#  array([[ 0.26318068, -0.19518001],
#         [-0.19738551,  0.        ],
#         [ 0.32897585, -0.68313005],
#         [-0.65795169, -0.39036003],
#         [-0.59215653, -0.58554004]]),
#  array([[ 0.39735971,  0.14948702],
#         [ 0.46358632, -0.44846106],
#         [-0.52981294,  0.        ],
#         [ 0.13245324, -0.52320456],
#         [ 0.19867985,  0.        ],
#         [-0.06622662,  0.59794807],
#         [ 0.46358632, -0.37371755],
#         [ 0.26490647, -0.07474351]]),
#  array([[-0.52400026,  0.        ],
#         [-0.40755576,  0.59299945],
#         [ 0.34933351, -0.59299945],
#         [ 0.40755576, -0.22237479],
#         [ 0.46577801, -0.44474959],
#         [-0.232889  , -0.22237479]]),
#  array([[ 0.10075854,  0.44232587],
#         [ 0.30227563,  0.44232587],
#         [-0.50379272, -0.22116293],
#         [ 0.40303418, -0.36860489],
#         [-0.40303418, -0.44232587],
#         [ 0.10075854,  0.29488391],
#         [ 0.15113782,  0.36860489],
#         [ 0.35265491,  0.        ],
#         [-0.40303418, -0.07372098]]),
#  array([[ 0.11846978,  0.38401229],
#         [-0.29617444,  0.24000768],
#         [-0.53311399, -0.14400461],
#         [ 0.35540933, -0.43201382],
#         [-0.05923489,  0.24000768],
#         [-0.29617444, -0.43201382],
#         [-0.53311399,  0.09600307],
#         [ 0.23693955, -0.43201382],
#         [-0.23693955, -0.38401229]]),
#  array([[ 0.34641016, -0.58338335],
#         [ 0.80829038, -0.58338335],
#         [ 0.        , -0.12964074],
#         [ 0.11547005,  0.38892223],
#         [ 0.46188022,  0.38892223]]),
#  array([[-0.19425717,  0.57854191],
#         [ 0.77702869,  0.51425948],
#         [ 0.09712859, -0.38569461],
#         [-0.09712859,  0.38569461],
#         [-0.58277152,  0.32141217]]),
#  array([[ 0.        , -0.77702869],
#         [ 0.36514837,  0.58277152],
#         [-0.18257419,  0.09712859],
#         [ 0.73029674, -0.09712859],
#         [ 0.54772256,  0.19425717]]),
#  array([[-0.55641488, -0.34299717],
#         [ 0.5007734 ,  0.08574929],
#         [ 0.27820744,  0.42874646],
#         [ 0.        , -0.60024505],
#         [ 0.11128298, -0.34299717],
#         [-0.38949042,  0.34299717],
#         [ 0.44513191, -0.17149859],
#         [ 0.        , -0.25724788]]),
#  array([[ 0.63245553,  0.56254395],
#         [ 0.        ,  0.22501758],
#         [ 0.73786479,  0.        ],
#         [ 0.10540926, -0.56254395],
#         [-0.21081851,  0.56254395]]),
#  array([[-0.57346234,  0.11043153],
#         [ 0.65538554, -0.99388373],
#         [ 0.49153915,  0.        ]]),
#  array([[-0.07537784,  0.        ],
#         [-0.07537784, -0.39056673],
#         [-0.67840053, -0.39056673],
#         [ 0.37688918, -0.78113347],
#         [-0.60302269,  0.13018891],
#         [ 0.15075567,  0.26037782]]),
#  array([[-0.2236068 , -0.14547859],
#         [-0.67082039, -0.72739297],
#         [ 0.67082039, -0.65465367],
#         [ 0.2236068 , -0.14547859]]),
#  array([[ 0.57735027,  0.23990406],
#         [ 0.44905021,  0.53978413],
#         [ 0.12830006, -0.17992804],
#         [-0.12830006,  0.29988007],
#         [ 0.51320024,  0.29988007],
#         [-0.25660012,  0.17992804],
#         [ 0.19245009, -0.4198321 ],
#         [ 0.25660012, -0.47980812]]),
#  array([[ 0.58501794,  0.40613847],
#         [-0.5118907 ,  0.10153462],
#         [-0.36563621,  0.81227693],
#         [-0.5118907 ,  0.40613847]]),
#  array([[-0.62554324, -0.16464639],
#         [ 0.27801922, -0.21952852],
#         [-0.34752402, -0.5488213 ],
#         [ 0.27801922, -0.21952852],
#         [ 0.41702883, -0.49393917],
#         [-0.13900961, -0.10976426],
#         [ 0.13900961, -0.27441065],
#         [-0.34752402,  0.49393917]]),
#  array([[ 0.17466675, -0.43528575],
#         [-0.58222251,  0.50783338],
#         [ 0.29111125, -0.14509525],
#         [ 0.46577801, -0.43528575],
#         [-0.52400026,  0.2901905 ],
#         [-0.232889  , -0.50783338]]),
#  array([[-0.09205746,  0.74420841],
#         [-0.82851716, -0.62017367],
#         [-0.55234477, -0.24806947]]),
#  array([[ 0.5284982 ,  0.07474351],
#         [ 0.46977618,  0.67269158],
#         [-0.46977618,  0.29897404],
#         [-0.5284982 , -0.67269158]]),
#  array([[-0.70710678, -0.66896473],
#         [-0.70710678, -0.74329415]]),
#  array([[ 0.36514837,  0.21199958],
#         [-0.42600643, -0.42399915],
#         [ 0.36514837, -0.21199958],
#         [-0.42600643,  0.8479983 ],
#         [-0.60858062, -0.10599979]]),
#  array([[ 0.57932412, -0.70436073],
#         [ 0.7448453 ,  0.35218036],
#         [ 0.33104236, -0.61631563]]),
#  array([[ 0.36214298,  0.51961524],
#         [ 0.36214298, -0.57735027],
#         [ 0.27160724, -0.34641016],
#         [ 0.        ,  0.28867513],
#         [-0.81482171, -0.17320508],
#         [ 0.        ,  0.40414519]]),
#  array([[-0.40894437,  0.24479602],
#         [-0.58420624, -0.48959205],
#         [ 0.17526187, -0.30599503],
#         [ 0.40894437, -0.61199006],
#         [-0.29210312, -0.30599503],
#         [ 0.29210312, -0.36719404],
#         [ 0.35052374, -0.06119901]]),
#  array([[ 0.56148993, -0.4463037 ],
#         [-0.63167617, -0.12751534],
#         [-0.07018624,  0.        ],
#         [ 0.21055872, -0.25503069],
#         [ 0.28074496,  0.51006137],
#         [ 0.28074496, -0.19127301],
#         [ 0.        , -0.12751534],
#         [ 0.28074496, -0.63757671]]),
#  array([[ 0.4472136 ,  0.89442719],
#         [-0.89442719, -0.4472136 ]]),
#  array([[ 0.31277162, -0.22423053],
#         [ 0.72980045,  0.59794807],
#         [ 0.52128604, -0.67269158],
#         [-0.31277162, -0.37371755]]),
#  array([[ 0.        , -0.55079106],
#         [ 0.32732684, -0.12239801],
#         [-0.49099025,  0.24479602],
#         [ 0.27277236, -0.42839304],
#         [-0.16366342, -0.12239801],
#         [-0.32732684,  0.30599503],
#         [ 0.10910895, -0.24479602],
#         [ 0.49099025,  0.36719404],
#         [-0.43643578, -0.36719404]]),
#  array([[-0.70710678, -0.4472136 ],
#         [-0.70710678, -0.89442719]]),
#  array([[-0.75592895, -0.41403934],
#         [-0.37796447, -0.55205245],
#         [ 0.30237158, -0.41403934],
#         [ 0.22677868,  0.48304589],
#         [ 0.37796447, -0.34503278]]),
#  array([[ 0.50495552,  0.        ],
#         [-0.56807496, -0.07235746],
#         [ 0.        ,  0.65121714],
#         [ 0.3155972 ,  0.57885968],
#         [ 0.        ,  0.21707238],
#         [-0.56807496, -0.43414476]])]

# %% [markdown]
# # Step 3. Visualization
#
# We will visualize vectors and directions using `matplotlib`

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
ax = plt.gca()
X = inputs[0]['X']
vecs = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*vecs)

print(X, Y, U, V)

ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'red')

X = answers['directions'][0] * 2
norms = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*norms)

print(X, Y, U, V)
ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'blue')
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
plt.draw()
plt.grid()
plt.legend(['original', 'normalized'])
plt.show()
# Out:
# (np.int64(0), np.int64(0)) (np.int64(0), np.int64(0)) (np.int64(1), np.int64(2)) (np.int64(3), np.int64(4))
# (np.float64(0.0), np.float64(0.0)) (np.float64(0.0), np.float64(0.0)) (np.float64(0.6324555320336759), np.float64(0.8944271909999159)) (np.float64(1.8973665961010275), np.float64(1.7888543819998317))

# %% [markdown]
# # Task 4. Scalar Product
#
# Write a function that calculates
# - cosine distance between the vectors
# - use $10^{-8}$ additional constant in the denominator for the sake of numerical stability

# %%
def get_cosine(X):
    res = None
    # res = (X[:, 0] * X[:, 1]).sum() / (np.linalg.norm(X[:, 0]) * np.linalg.norm(X[:, 1]) + 1e-8)
    length = get_lengths(X)
    denorm = np.prod(length) + 1e-8
    numer = (np.prod(X,axis = 1)).sum()
    res = numer/ denorm
    return res

# %%
answers['cosine'] = [
    get_cosine(**inp) for inp in inputs
]

# %%
print(answers['cosine'][0])
# Out:
# 0.9899494929611663

# %% [markdown]
# # Task 5. Orthonormalization
#
# Create a pair of orthonormal vectors
# - Take the first vector and normalize it
# - Take the second vector, remove the collinear component to the first one
# - Normalize it

# %%
def get_orthonormal(X):
    res = X.copy().astype('float32')
    lenght = get_lengths(X[:, 0])
    dir = get_directions(X[: , 0])
    # res[0] = dir[:, 0]
    v2 = X[:, 1]
    proj = get_lengths(v2) * get_cosine(X)
    v2_ort = (v2 - (proj * dir))
    norm_v2 = get_directions(v2_ort)  
    res = np.array([dir, norm_v2]).T.astype('float32')

    return res

# %%
answers['orthonormal'] = [
    get_orthonormal(**inp) for inp in inputs
]
answers['orthonormal']
# Out:
# [array([[ 0.31622776,  0.9486833 ],
#         [ 0.9486833 , -0.31622776]], dtype=float32),
#  array([[ 0.22941573, -0.05777823],
#         [-0.1720618 , -0.23996603],
#         [ 0.45883146, -0.11555646],
#         [ 0.        , -0.4957745 ],
#         [-0.1720618 , -0.5232658 ],
#         [-0.5161854 ,  0.20082594],
#         [-0.28676966, -0.5652016 ],
#         [-0.5735393 ,  0.2152705 ]], dtype=float32),
#  array([[-0.7683498 ,  0.376591  ],
#         [ 0.5488213 ,  0.80367464],
#         [-0.32929277,  0.4607454 ]], dtype=float32),
#  array([[-0.37139067, -0.9284767 ],
#         [-0.9284767 ,  0.37139067]], dtype=float32),
#  array([[-0.4472136 , -0.38335723],
#         [-0.3354102 ,  0.15547265],
#         [-0.2236068 ,  0.01277857],
#         [-0.2236068 ,  0.01277857],
#         [-0.1677051 ,  0.17996493],
#         [-0.5031153 , -0.34608638],
#         [ 0.2795085 , -0.5952686 ],
#         [-0.4472136 ,  0.36631915],
#         [-0.1677051 , -0.43340665]], dtype=float32),
#  array([[ 0.        , -0.37098786],
#         [-0.6375767 , -0.09802525],
#         [ 0.57381904, -0.56100607],
#         [-0.12751535, -0.5760869 ],
#         [-0.2550307 , -0.13195707],
#         [-0.19127302,  0.06333939],
#         [-0.38254604, -0.429803  ]], dtype=float32),
#  array([[ 0.5340518 , -0.08274336],
#         [-0.5933908 , -0.15106808],
#         [-0.23735633,  0.32114255],
#         [-0.17801724, -0.46876982],
#         [ 0.        ,  0.3257303 ],
#         [-0.05933908, -0.37341014],
#         [-0.23735633,  0.22807676],
#         [ 0.2966954 ,  0.4245308 ],
#         [ 0.3560345 , -0.41191447]], dtype=float32),
#  array([[-0.48867777, -0.6124146 ],
#         [ 0.5497625 , -0.4767091 ],
#         [-0.48867777,  0.32012582],
#         [-0.06108472, -0.4468252 ],
#         [-0.18325417,  0.14061792],
#         [ 0.42759305,  0.2753    ]], dtype=float32),
#  array([[ 0.48809353,  0.2459448 ],
#         [ 0.10846523,  0.37113005],
#         [-0.05423262,  0.4324582 ],
#         [ 0.32539567,  0.41475523],
#         [-0.32539567, -0.09230833],
#         [ 0.05423262, -0.5399405 ],
#         [-0.54232615,  0.24025455],
#         [-0.48809353,  0.2914667 ]], dtype=float32),
#  array([[ 0.70710677,  0.07106691],
#         [ 0.        , -0.9949367 ],
#         [-0.70710677,  0.07106691]], dtype=float32),
#  array([[ 0.3227486 ,  0.0051732 ],
#         [ 0.5163978 ,  0.24003653],
#         [-0.45184806,  0.30728814],
#         [-0.12909944,  0.72631747],
#         [ 0.06454972, -0.19761628],
#         [-0.2581989 ,  0.37660906],
#         [ 0.5809475 ,  0.37350512]], dtype=float32),
#  array([[-0.22056438,  0.30746233],
#         [ 0.14704293, -0.59470105],
#         [ 0.66169316,  0.30525038],
#         [-0.29408586,  0.13714147],
#         [-0.5146502 , -0.3738211 ],
#         [-0.36760733,  0.49295092],
#         [ 0.07352147, -0.2388916 ]], dtype=float32),
#  array([[ 0.5118907 , -0.005127  ],
#         [-0.14625448,  0.8574915 ],
#         [ 0.21938172,  0.27173123],
#         [-0.7312724 , -0.26660421],
#         [ 0.3656362 , -0.3460728 ]], dtype=float32),
#  array([[-0.42966893, -0.11954606],
#         [-0.5012804 ,  0.54940313],
#         [-0.14322297, -0.81138706],
#         [ 0.6445034 ,  0.09665426],
#         [ 0.35805744,  0.12717666]], dtype=float32),
#  array([[-0.3656362 ,  0.87766045],
#         [-0.43876344, -0.16595043],
#         [-0.3656362 , -0.41537   ],
#         [-0.43876344, -0.16595043],
#         [-0.07312724, -0.0276584 ],
#         [ 0.5850179 ,  0.03654861]], dtype=float32),
#  array([[-0.45056355, -0.23894478],
#         [-0.45056355,  0.4976698 ],
#         [ 0.        ,  0.        ],
#         [ 0.25031307, -0.15956026],
#         [ 0.40050095,  0.16562618],
#         [ 0.25031307, -0.15956026],
#         [ 0.25031307, -0.4752522 ],
#         [-0.35043833, -0.09230759],
#         [-0.35043833, -0.61846083]], dtype=float32),
#  array([[ 0.0805823 ,  0.34699076],
#         [ 0.1611646 ,  0.52104765],
#         [-0.56407607, -0.06550527],
#         [-0.6446584 , -0.12427285],
#         [ 0.1611646 ,  0.40575835],
#         [ 0.3223292 , -0.39902067],
#         [ 0.3223292 , -0.51430994]], dtype=float32),
#  array([[-0.11867817, -0.4932224 ],
#         [ 0.47471267, -0.22559948],
#         [-0.3560345 , -0.41182965],
#         [-0.2966954 , -0.5421023 ],
#         [ 0.5340518 , -0.04180226],
#         [-0.4153736 ,  0.28376877],
#         [-0.2966954 ,  0.40010732]], dtype=float32),
#  array([[ 0.5388159 , -0.5424311 ],
#         [ 0.08980265,  0.37187287],
#         [ 0.26940796, -0.09786128],
#         [-0.1796053 , -0.45482194],
#         [ 0.08980265, -0.49489847],
#         [-0.7184212 , -0.31688413],
#         [-0.26940796, -0.07549299]], dtype=float32),
#  array([[-0.7808688 , -0.62469506],
#         [ 0.62469506, -0.7808688 ]], dtype=float32),
#  array([[-0.8944272 ,  0.44414836],
#         [ 0.        , -0.11688115],
#         [-0.4472136 , -0.8882967 ]], dtype=float32),
#  array([[ 0.08574929,  0.08361412],
#         [-0.60024506,  0.59106535],
#         [-0.60024506, -0.4872685 ],
#         [-0.51449573, -0.20759368],
#         [-0.08574929,  0.6025983 ]], dtype=float32),
#  array([[-0.21693046, -0.97618705],
#         [ 0.97618705, -0.21693046]], dtype=float32),
#  array([[-0.6237829 ,  0.22960417],
#         [ 0.        ,  0.48480976],
#         [ 0.37426972, -0.16546592],
#         [ 0.37426972,  0.73489505],
#         [-0.12475657,  0.37836182],
#         [ 0.5614046 , -0.04042327]], dtype=float32),
#  array([[ 0.19653654,  0.45099023],
#         [ 0.45858526, -0.07604085],
#         [-0.06551218, -0.3183824 ],
#         [-0.6551218 ,  0.27325246],
#         [ 0.3275609 ,  0.7276429 ],
#         [-0.45858526,  0.29210812]], dtype=float32),
#  array([[-0.10783277, -0.76603836],
#         [-0.21566555, -0.6041993 ],
#         [-0.970495  ,  0.21938188]], dtype=float32),
#  array([[-0.5726563 ,  0.48651245],
#         [-0.38177085, -0.6269929 ],
#         [-0.44539934,  0.4451589 ],
#         [ 0.5726563 ,  0.41475186]], dtype=float32),
#  array([[ 0.11624764,  0.6870127 ],
#         [ 0.6974858 , -0.41055214],
#         [ 0.6974858 ,  0.20196517],
#         [ 0.11624764,  0.5645092 ]], dtype=float32),
#  array([[ 0.42919755,  0.3708603 ],
#         [-0.24525574, -0.3862268 ],
#         [ 0.42919755, -0.23921292],
#         [-0.24525574,  0.46787572],
#         [ 0.1839418 , -0.5644324 ],
#         [ 0.06131393,  0.0965567 ],
#         [-0.5518254 , -0.2589371 ],
#         [-0.3678836 ,  0.15274766],
#         [-0.1839418 ,  0.13738115]], dtype=float32),
#  array([[-0.5547002,  0.8320503],
#         [-0.8320503, -0.5547002]], dtype=float32),
#  array([[-0.48666427,  0.84119105],
#         [-0.8111071 , -0.53530335],
#         [ 0.32444283, -0.07647191]], dtype=float32),
#  array([[-0.7552632 , -0.19611613],
#         [ 0.5035088 , -0.78446454],
#         [-0.41959068, -0.5883484 ]], dtype=float32),
#  array([[-0.5039526 , -0.18131351],
#         [ 0.12598816,  0.22280051],
#         [-0.12598816, -0.41640645],
#         [ 0.18898223, -0.44022307],
#         [-0.5669467 ,  0.15903346],
#         [-0.12598816, -0.48094177],
#         [-0.12598816, -0.48094177],
#         [-0.5669467 ,  0.22356878],
#         [-0.06299408, -0.11140025]], dtype=float32),
#  array([[ 0.17277369, -0.24712783],
#         [-0.6047079 , -0.34832242],
#         [-0.34554738, -0.64764535],
#         [ 0.        ,  0.28547525],
#         [ 0.69109476, -0.56029844],
#         [-0.08638684,  0.0521951 ]], dtype=float32),
#  array([[ 0.26726124, -0.2035896 ],
#         [-0.4677072 ,  0.28127512],
#         [-0.4677072 ,  0.18126619],
#         [-0.4677072 ,  0.13126172],
#         [ 0.06681531,  0.32413608],
#         [-0.06681531, -0.52415395],
#         [ 0.4677072 ,  0.5187963 ],
#         [ 0.20044594,  0.27234575],
#         [ 0.06681531, -0.32592195]], dtype=float32),
#  array([[-0.44444445,  0.22158371],
#         [ 0.05555556,  0.28573707],
#         [ 0.2777778 , -0.28695905],
#         [ 0.5       , -0.1338056 ],
#         [ 0.44444445, -0.22158371],
#         [-0.44444445, -0.83419746],
#         [-0.2777778 ,  0.1549864 ]], dtype=float32),
#  array([[-0.3617873 ,  0.6170844 ],
#         [-0.65121716, -0.15206723],
#         [ 0.        ,  0.21046986],
#         [ 0.43414477, -0.4247965 ],
#         [ 0.5065022 ,  0.6093708 ]], dtype=float32),
#  array([[-0.13102436,  0.2886803 ],
#         [ 0.06551218,  0.16948181],
#         [ 0.26204872,  0.31180164],
#         [ 0.5896096 , -0.4098991 ],
#         [-0.06551218, -0.16948181],
#         [ 0.45858526, -0.43504074],
#         [-0.5896096 , -0.63617414]], dtype=float32),
#  array([[ 0.5246722 ,  0.39353296],
#         [ 0.29981267, -0.32675776],
#         [ 0.        ,  0.54301447],
#         [ 0.37476584, -0.5291171 ],
#         [-0.37476584, -0.37590703],
#         [-0.14990634, -0.01762594],
#         [ 0.2248595 , -0.0640635 ],
#         [ 0.5246722 , -0.08914657],
#         [ 0.07495317,  0.09931538]], dtype=float32),
#  array([[ 0.16666667,  0.2944851 ],
#         [ 0.        , -0.05989527],
#         [-0.6666667 , -0.03993018],
#         [ 0.41666666,  0.07736473],
#         [-0.08333334,  0.03244327],
#         [-0.16666667, -0.65385675],
#         [-0.5       ,  0.37434548],
#         [-0.25      , -0.08235601],
#         [ 0.08333334, -0.5715007 ]], dtype=float32),
#  array([[ 0.49621683, -0.2696244 ],
#         [-0.21266437,  0.77460325],
#         [-0.7088812 , -0.05896459],
#         [-0.3544406 , -0.4807882 ],
#         [ 0.28355247,  0.30439842]], dtype=float32),
#  array([[ 0.49613893,  0.3779663 ],
#         [ 0.        , -0.718357  ],
#         [-0.24806947,  0.17019536],
#         [-0.6201737 , -0.22103293],
#         [-0.24806947,  0.17019536],
#         [ 0.49613893, -0.48406214]], dtype=float32),
#  array([[-0.5163978 , -0.2594066 ],
#         [ 0.3227486 , -0.5674519 ],
#         [-0.3227486 ,  0.03074863],
#         [-0.38729835, -0.64739835],
#         [ 0.3227486 , -0.36618817],
#         [ 0.2581989 ,  0.09615934],
#         [-0.45184806,  0.21747664]], dtype=float32),
#  array([[-0.57735026, -0.06930296],
#         [ 0.6598289 , -0.40938252],
#         [ 0.24743582, -0.41730285],
#         [ 0.41239306,  0.8083696 ]], dtype=float32),
#  array([[-0.14865883, -0.0319877 ],
#         [ 0.29731765, -0.43514296],
#         [-0.07432941, -0.21564119],
#         [ 0.37164706,  0.17979291],
#         [-0.4459765 , -0.19578676],
#         [ 0.52030593,  0.21178061],
#         [-0.52030593,  0.18751408],
#         [-0.07432941,  0.7825955 ]], dtype=float32),
#  array([[-0.9938837 , -0.11043153],
#         [ 0.11043153, -0.9938837 ]], dtype=float32),
#  array([[-0.56568545, -0.48227704],
#         [ 0.6363961 , -0.3464673 ],
#         [ 0.07071068, -0.49006662],
#         [-0.42426407,  0.23097818],
#         [ 0.28284273,  0.2750063 ],
#         [-0.07071068,  0.35459554],
#         [ 0.07071068,  0.39049536]], dtype=float32),
#  array([[ 0.78935224, -0.6139406 ],
#         [ 0.6139406 ,  0.78935224]], dtype=float32),
#  array([[-0.13671719, -0.7295971 ],
#         [ 0.        , -0.53287977],
#         [ 0.61522734, -0.1805317 ],
#         [ 0.47851014, -0.11080911],
#         [-0.54686874, -0.25398943],
#         [ 0.27343437, -0.2726651 ]], dtype=float32),
#  array([[-0.66436386, -0.74740934],
#         [-0.74740934,  0.66436386]], dtype=float32),
#  array([[ 0.5547002, -0.8320503],
#         [-0.8320503, -0.5547002]], dtype=float32),
#  array([[-0.60268456,  0.02052513],
#         [-0.60268456,  0.10225913],
#         [ 0.46875468,  0.24740112],
#         [-0.13392991,  0.6765963 ],
#         [-0.13392991, -0.63114774],
#         [-0.13392991,  0.26792625]], dtype=float32),
#  array([[-0.58277154, -0.14710967],
#         [-0.48564294,  0.78309894],
#         [-0.09712858, -0.22140749],
#         [-0.58277154, -0.22586535],
#         [ 0.19425717,  0.3640593 ],
#         [ 0.19425717,  0.3640593 ]], dtype=float32),
#  array([[-0.3721042 ,  0.5841636 ],
#         [ 0.49613893,  0.43478844],
#         [ 0.24806947,  0.6508489 ],
#         [-0.7442084 ,  0.2147268 ]], dtype=float32),
#  array([[ 0.37688917,  0.24704175],
#         [-0.22613351, -0.10845735],
#         [-0.15075567, -0.5362614 ],
#         [ 0.30151135,  0.34344828],
#         [-0.6030227 ,  0.6386933 ],
#         [-0.5276449 , -0.25306717],
#         [ 0.22613351, -0.22294012]], dtype=float32),
#  array([[ 0.4153393 , -0.38319921],
#         [ 0.05191741,  0.3005484 ],
#         [-0.31150448,  0.36483237],
#         [-0.15575224, -0.04988269],
#         [ 0.25958708, -0.27821597],
#         [-0.51917416,  0.16926719],
#         [-0.31150448, -0.5643631 ],
#         [-0.51917416, -0.45019644]], dtype=float32),
#  array([[ 0.5009794 ,  0.09191862],
#         [ 0.18786728,  0.35084432],
#         [ 0.12524486, -0.0045312 ],
#         [-0.31311214, -0.23626971],
#         [ 0.5009794 ,  0.03689691],
#         [ 0.12524486, -0.44470492],
#         [ 0.37573457, -0.7288759 ],
#         [ 0.438357  ,  0.2867602 ]], dtype=float32),
#  array([[-0.14142136, -0.98994946],
#         [-0.98994946,  0.14142136]], dtype=float32),
#  array([[-0.57346237, -0.14433126],
#         [-0.08192319, -0.3257339 ],
#         [-0.65538555, -0.02817425],
#         [-0.08192319,  0.33710244],
#         [ 0.40961596,  0.08205133],
#         [ 0.16384639, -0.3059625 ],
#         [ 0.08192319, -0.116157  ],
#         [ 0.16384639, -0.45325947],
#         [ 0.        ,  0.6628364 ]], dtype=float32),
#  array([[ 0.57346237, -0.791169  ],
#         [-0.65538555, -0.28735855],
#         [ 0.49153915,  0.53988576]], dtype=float32),
#  array([[-0.47043753, -0.5588767 ],
#         [-0.05227084, -0.374505  ],
#         [-0.47043753,  0.3996466 ],
#         [-0.47043753,  0.01623728],
#         [-0.47043753,  0.3996466 ],
#         [ 0.26135418,  0.46669087],
#         [-0.20908335,  0.09951881]], dtype=float32),
#  array([[-0.0574485 ,  0.49525335],
#         [-0.2872425 ,  0.1398486 ],
#         [-0.5170365 , -0.05625489],
#         [ 0.2872425 , -0.5115515 ],
#         [ 0.114897  , -0.45950258],
#         [ 0.40213948, -0.12144748],
#         [-0.1723455 , -0.21345314],
#         [-0.574485  , -0.35750774],
#         [-0.1723455 , -0.26655355]], dtype=float32),
#  array([[ 0.6139406 , -0.35291365],
#         [ 0.7016464 ,  0.24518211],
#         [ 0.        , -0.869282  ],
#         [ 0.3508232 ,  0.1708845 ],
#         [ 0.0877058 , -0.17459938]], dtype=float32),
#  array([[ 0.56011206, -0.12456352],
#         [ 0.56011206, -0.32517636],
#         [ 0.42008403,  0.75918186],
#         [ 0.42008403, -0.3107532 ],
#         [ 0.14002801,  0.45367345]], dtype=float32),
#  array([[ 0.45584232,  0.21121877],
#         [ 0.51282257,  0.41625124],
#         [-0.17094086,  0.20149742],
#         [-0.28490144,  0.33582902],
#         [ 0.45584232,  0.21121877],
#         [ 0.45584232, -0.53732646],
#         [-0.05698029,  0.54351276]], dtype=float32),
#  array([[-0.18650097,  0.34098038],
#         [ 0.5595029 ,  0.2733479 ],
#         [ 0.09325048, -0.5269697 ],
#         [ 0.        ,  0.19444336],
#         [ 0.65275335, -0.44806513],
#         [ 0.46625242,  0.5410598 ]], dtype=float32),
#  array([[ 0.59805036,  0.23360093],
#         [ 0.08543576, -0.29149508],
#         [-0.2563073 ,  0.48623   ],
#         [-0.08543576, -0.5404805 ],
#         [ 0.17087153,  0.30445042],
#         [-0.6834861 , -0.05303591],
#         [ 0.2563073 , -0.48623   ]], dtype=float32),
#  array([[ 0.53033006, -0.34586018],
#         [ 0.        , -0.20686965],
#         [-0.17677669, -0.53980047],
#         [ 0.53033006, -0.449295  ],
#         [ 0.53033006,  0.5850532 ],
#         [-0.35355338, -0.04525274]], dtype=float32),
#  array([[ 0.76626104,  0.61775494],
#         [-0.28734788,  0.5754429 ],
#         [ 0.57469577, -0.53595173]], dtype=float32),
#  array([[ 0.5467111 , -0.33204883],
#         [-0.5467111 , -0.46428066],
#         [-0.4859654 ,  0.33939505],
#         [-0.18223703, -0.73873514],
#         [ 0.36447406, -0.11518862]], dtype=float32),
#  array([[ 0.26318067, -0.2977825 ],
#         [-0.1973855 ,  0.0684095 ],
#         [ 0.32897586, -0.83701026],
#         [-0.6579517 , -0.18510804],
#         [-0.5921565 , -0.41448104]], dtype=float32),
#  array([[ 0.3973597 ,  0.36791846],
#         [ 0.46358633, -0.26841158],
#         [-0.52981293, -0.26731002],
#         [ 0.13245323, -0.5191983 ],
#         [ 0.19867985,  0.10024126],
#         [-0.06622662,  0.63633007],
#         [ 0.46358633, -0.1846936 ],
#         [ 0.26490647,  0.04993704]], dtype=float32),
#  array([[-0.5240003 , -0.50626427],
#         [-0.40755576,  0.4307963 ],
#         [ 0.3493335 , -0.48704788],
#         [ 0.40755576,  0.08455207],
#         [ 0.465778  , -0.16840535],
#         [-0.232889  , -0.53421533]], dtype=float32),
#  array([[ 0.10075855,  0.44250378],
#         [ 0.30227563,  0.3452776 ],
#         [-0.5037927 , -0.00249298],
#         [ 0.40303418, -0.60371643],
#         [-0.40303418, -0.2966645 ],
#         [ 0.10075855,  0.27879816],
#         [ 0.15113781,  0.33634442],
#         [ 0.3526549 , -0.17014582],
#         [-0.40303418,  0.11259955]], dtype=float32),
#  array([[ 0.11846977,  0.39058754],
#         [-0.29617444,  0.22514437],
#         [-0.533114  , -0.17151448],
#         [ 0.35540932, -0.41436684],
#         [-0.05923489,  0.23728698],
#         [-0.29617444, -0.44775903],
#         [-0.533114  ,  0.06880817],
#         [ 0.23693955, -0.42043814],
#         [-0.23693955, -0.39665884]], dtype=float32),
#  array([[ 0.34641016, -0.47881433],
#         [ 0.80829036, -0.24666193],
#         [ 0.        , -0.14509524],
#         [ 0.11547005,  0.49332386],
#         [ 0.4618802 ,  0.66743815]], dtype=float32),
#  array([[-0.19425717,  0.5835754 ],
#         [ 0.7770287 ,  0.49500787],
#         [ 0.09712858, -0.38824147],
#         [-0.09712858,  0.38824147],
#         [-0.58277154,  0.33607152]], dtype=float32),
#  array([[ 0.        , -0.7985374 ],
#         [ 0.36514837,  0.5123948 ],
#         [-0.18257418,  0.14307128],
#         [ 0.73029673, -0.2728336 ],
#         [ 0.5477226 ,  0.06987202]], dtype=float32),
#  array([[-0.5564149 , -0.286173  ],
#         [ 0.5007734 ,  0.03336905],
#         [ 0.27820745,  0.40176338],
#         [ 0.        , -0.6035794 ],
#         [ 0.11128297, -0.35664842],
#         [-0.38949043,  0.38601318],
#         [ 0.4451319 , -0.21943487],
#         [ 0.        , -0.2586769 ]], dtype=float32),
#  array([[ 0.6324555 ,  0.45732957],
#         [ 0.        ,  0.22866479],
#         [ 0.7378648 , -0.13338779],
#         [ 0.10540926, -0.5907174 ],
#         [-0.21081851,  0.60977274]], dtype=float32),
#  array([[-0.57346237, -0.42810136],
#         [ 0.65538555, -0.7512967 ],
#         [ 0.49153915,  0.5022773 ]], dtype=float32),
#  array([[-0.07537784, -0.00296112],
#         [-0.07537784, -0.3938291 ],
#         [-0.6784005 , -0.41751808],
#         [ 0.37688917, -0.76693034],
#         [-0.6030227 ,  0.10660036],
#         [ 0.15075567,  0.2665009 ]], dtype=float32),
#  array([[-0.2236068 , -0.13472818],
#         [-0.6708204 , -0.69548875],
#         [ 0.6708204 , -0.68820614],
#         [ 0.2236068 , -0.156576  ]], dtype=float32),
#  array([[ 0.57735026,  0.11393986],
#         [ 0.44905022,  0.45094866],
#         [ 0.12830006, -0.21395373],
#         [-0.12830006,  0.3370088 ],
#         [ 0.5132002 ,  0.19015297],
#         [-0.2566001 ,  0.2433249 ],
#         [ 0.19245009, -0.47474942],
#         [ 0.2566001 , -0.5509625 ]], dtype=float32),
#  array([[ 0.5850179 ,  0.6256642 ],
#         [-0.5118907 , -0.06531659],
#         [-0.3656362 ,  0.7339522 ],
#         [-0.5118907 ,  0.25610977]], dtype=float32),
#  array([[-0.62554324, -0.31621066],
#         [ 0.27801922, -0.16014804],
#         [-0.34752402, -0.64549464],
#         [ 0.27801922, -0.16014804],
#         [ 0.4170288 , -0.409358  ],
#         [-0.13900961, -0.14544056],
#         [ 0.13900961, -0.24920996],
#         [-0.34752402,  0.42569962]], dtype=float32),
#  array([[ 0.17466675, -0.42351326],
#         [-0.5822225 ,  0.16998813],
#         [ 0.29111126,  0.05828164],
#         [ 0.465778  , -0.17419735],
#         [-0.5240003 , -0.0667001 ],
#         [-0.232889  , -0.8680727 ]], dtype=float32),
#  array([[-0.09205746,  0.98138547],
#         [-0.82851714, -0.16938274],
#         [-0.5523448 ,  0.09050986]], dtype=float32),
#  array([[ 0.5284982 , -0.27617708],
#         [ 0.46977618,  0.492725  ],
#         [-0.46977618,  0.6904427 ],
#         [-0.5284982 , -0.4519261 ]], dtype=float32),
#  array([[-0.70710677,  0.70710677],
#         [-0.70710677, -0.70710677]], dtype=float32),
#  array([[ 0.36514837,  0.2561321 ],
#         [-0.42600644, -0.47669026],
#         [ 0.36514837, -0.17075472],
#         [-0.42600644,  0.80397016],
#         [-0.60858065, -0.1778695 ]], dtype=float32),
#  array([[ 0.5793241 , -0.5355629 ],
#         [ 0.7448453 ,  0.6540047 ],
#         [ 0.33104235, -0.5342755 ]], dtype=float32),
#  array([[ 0.36214298,  0.5103248 ],
#         [ 0.36214298, -0.58701557],
#         [ 0.27160725, -0.35362953],
#         [ 0.        ,  0.28877378],
#         [-0.8148217 , -0.15196128],
#         [ 0.        ,  0.4042833 ]], dtype=float32),
#  array([[-0.40894437,  0.18273927],
#         [-0.5842062 , -0.58882654],
#         [ 0.17526187, -0.28193456],
#         [ 0.40894437, -0.5545629 ],
#         [-0.2921031 , -0.3563839 ],
#         [ 0.2921031 , -0.32529283],
#         [ 0.35052374, -0.00613361]], dtype=float32),
#  array([[ 0.56148994, -0.2847512 ],
#         [-0.63167614, -0.34262747],
#         [-0.07018624, -0.02315051],
#         [ 0.21055873, -0.19909434],
#         [ 0.28074497,  0.62969375],
#         [ 0.28074497, -0.10880738],
#         [ 0.        , -0.13427293],
#         [ 0.28074497, -0.57876265]], dtype=float32),
#  array([[ 0.4472136,  0.8944272],
#         [-0.8944272,  0.4472136]], dtype=float32),
#  array([[ 0.31277162, -0.26802665],
#         [ 0.72980046,  0.50572616],
#         [ 0.521286  , -0.7483436 ],
#         [-0.31277162, -0.33523825]], dtype=float32),
#  array([[ 0.        , -0.5513106 ],
#         [ 0.32732683, -0.10829315],
#         [-0.49099025,  0.22369646],
#         [ 0.27277237, -0.41694686],
#         [-0.16366342, -0.12962362],
#         [-0.32732683,  0.29206336],
#         [ 0.10910895, -0.24028683],
#         [ 0.49099025,  0.38887087],
#         [-0.4364358 , -0.3865008 ]], dtype=float32),
#  array([[-0.70710677,  0.70710677],
#         [-0.70710677, -0.70710677]], dtype=float32),
#  array([[-0.75592893, -0.14040583],
#         [-0.37796447, -0.44249108],
#         [ 0.3023716 , -0.5692818 ],
#         [ 0.22677869,  0.42930147],
#         [ 0.37796447, -0.52545816]], dtype=float32),
#  array([[ 0.50495553, -0.2691843 ],
#         [-0.56807494,  0.22083566],
#         [ 0.        ,  0.73797005],
#         [ 0.3155972 ,  0.4877332 ],
#         [ 0.        ,  0.24599002],
#         [-0.56807494, -0.18914771]], dtype=float32)]

# %% [markdown]
# # 6. Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
ax = plt.gca()
X = inputs[0]['X']
print(X)
vecs = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*vecs)
ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'red')

X = answers['orthonormal'][0]
print(X)
norms = np.concatenate([np.zeros_like(X), X.T], axis=1)
X, Y, U, V = zip(*norms)
ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color = 'blue')
ax.set_xlim([-5, 5])
ax.set_ylim([-5, 5])
plt.draw()
plt.grid()
plt.legend(['original', 'orthonormalized'])
plt.show()
# Out:
# [[1 2]
#  [3 4]]
# [[ 0.31622776  0.9486833 ]
#  [ 0.9486833  -0.31622776]]

# %% [markdown]
# # 7. Saving the answer

# %%
json_tricks.dump(answers, '.answer.json')
# Out:
# '{"lengths": [{"__ndarray__": [3.1622776601683795, 4.47213595499958], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.435595774162696, 14.560219778561036], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.1104335791443, 5.830951894845301], "dtype": "float64", "shape": [2]}, {"__ndarray__": [10.770329614269007, 2.23606797749979], "dtype": "float64", "shape": [2]}, {"__ndarray__": [17.88854381999832, 17.635192088548397], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.684387141358123, 17.69180601295413], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.852299546352718, 21.494185260204677], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.3707055437449, 18.384776310850235], "dtype": "float64", "shape": [2]}, {"__ndarray__": [18.439088914585774, 18.627936010197157], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.899494936611665, 7.3484692283495345], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.491933384829668, 13.490737563232042], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.601470508735444, 17.146428199482248], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.674794331177344, 11.489125293076057], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.96424004376894, 12.165525060596439], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.674794331177344, 14.45683229480096], "dtype": "float64", "shape": [2]}, {"__ndarray__": [19.974984355438178, 11.269427669584644], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.409673645990857, 17.349351572897472], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.852299546352718, 15.968719422671311], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.135528725660043, 18.411952639521967], "dtype": "float64", "shape": [2]}, {"__ndarray__": [6.4031242374328485, 7.280109889280518], "dtype": "float64", "shape": [2]}, {"__ndarray__": [6.708203932499369, 10.344080432788601], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.661903789690601, 10.344080432788601], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.219544457292887, 8.0], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.0312195418814, 15.066519173319364], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.264337522473747, 15.297058540778355], "dtype": "float64", "shape": [2]}, {"__ndarray__": [9.273618495495704, 10.488088481701515], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.716233645501712, 14.0], "dtype": "float64", "shape": [2]}, {"__ndarray__": [8.602325267042627, 8.831760866327848], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.30950643030009, 17.74823934929885], "dtype": "float64", "shape": [2]}, {"__ndarray__": [7.211102550927978, 13.45362404707371], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.328828005937952, 6.164414002968976], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.916375287812984, 10.198039027185569], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.874507866387544, 16.09347693943108], "dtype": "float64", "shape": [2]}, {"__ndarray__": [11.575836902790225, 8.18535277187245], "dtype": "float64", "shape": [2]}, {"__ndarray__": [14.966629547095765, 21.2602916254693], "dtype": "float64", "shape": [2]}, {"__ndarray__": [18.0, 16.278820596099706], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.820274961085254, 9.797958971132712], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.264337522473747, 19.467922333931785], "dtype": "float64", "shape": [2]}, {"__ndarray__": [13.341664064126334, 17.233687939614086], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.0, 17.578395831246947], "dtype": "float64", "shape": [2]}, {"__ndarray__": [14.106735979665885, 10.535653752852738], "dtype": "float64", "shape": [2]}, {"__ndarray__": [16.1245154965971, 15.394804318340652], "dtype": "float64", "shape": [2]}, {"__ndarray__": [15.491933384829668, 15.0], "dtype": "float64", "shape": [2]}, {"__ndarray__": [12.12435565298214, 14.66287829861518], "dtype": "float64", "shape": [2]}, {"_ ...
